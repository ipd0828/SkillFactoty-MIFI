# %% [markdown]
# # Задачи регрессии IC50

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error, r2_score, make_scorer

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,  FunctionTransformer
from sklearn.pipeline import Pipeline

from catboost import  Pool
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin'

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
# Прочитаем обработанный датасет
df = pd.read_csv('./data_him.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    IC50, mM    CC50, mM         SI  MaxAbsEStateIndex  \
# 0           0    6.239374  175.482382  28.125000           5.094096
# 1           1    0.771831    5.402819   7.000000           3.961417
# 2           2  223.808778  161.142320   0.720000           2.627117
# 3           3    1.705624  107.855654  63.235294           5.097360
# 4           4  107.131532  139.270991   1.300000           5.150510
#
#    MaxEStateIndex  MinAbsEStateIndex  MinEStateIndex       qed        SPS  \
# 0        5.094096           0.387225        0.387225  0.417362  42.928571
# 1        3.961417           0.533868        0.533868  0.462473  45.214286
# 2        2.627117           0.543231        0.543231  0.260923  42.187500
# 3        5.097360           0.390603        0.390603  0.377846  41.862069
# 4        5.150510           0.270476        0.270476  0.429038  36.514286
#
#    ...  Polar_Groups_Count  Lipophilic_Groups_Count  PLB  HBond_Capacity  \
# 0  ...                   0                        3  0.0               2
# 1  ...                   0                        3  0.0               4
# 2  ...                   0                        3  0.0               0
# 3  ...                   0                        4  0.0               2
# 4  ...                   0                        0  0.0               2
#
#    HBond_Donor_Acceptor_Ratio  Saturation_Index  Hydrophobic_VSA  \
# 0                         0.0          1.000000       173.744106
# 1                         1.0          1.000000       175.053185
# 2                         0.0          1.000000       201.576358
# 3                         0.0          1.000000       180.164927
# 4                         0.0          0.666667       201.049968
#
#    BCUT_Electronic  Size_Flexibility    LogD
# 0        38.545778          26.92564  7.1212
# 1        39.145933          34.98156  6.1556
# 2        40.922447          40.21272  7.1292
# 3        38.542997          31.89432  7.5113
# 4        38.597756          18.66852  9.1148
#
# [5 rows x 213 columns]

# %%
df.shape
# Out:
# (970, 213)

# %%
cat_features = ['NumAliphaticCarbocycles', 'NumAliphaticHeterocycles', 'NumAliphaticRings', 
                'NumAromaticCarbocycles', 'NumAromaticHeterocycles', 'NumAromaticRings', 
                'NumSaturatedCarbocycles', 'NumSaturatedHeterocycles', 'NumSaturatedRings',
                'RingCount', 'fr_Al_OH', 'fr_Al_OH_noTert', 'fr_ArN', 'fr_Ar_N', 'fr_Ar_OH',
                'fr_C_O', 'fr_C_O_noCOO', 'fr_Imine', 'fr_NH1', 'fr_NH2', 'fr_Ndealkylation1', 
                'fr_Ndealkylation2', 'fr_alkyl_halide', 'fr_allylic_oxid', 'fr_amide', 'fr_aniline',
                'fr_aryl_methyl', 'fr_benzene', 'fr_bicyclic', 'fr_epoxide', 'fr_ester', 
                'fr_ether', 'fr_furan', 'fr_halogen', 'fr_hdrzone', 'fr_ketone', 'fr_ketone_Topliss',
                'fr_lactone', 'fr_methoxy', 'fr_morpholine', 'fr_oxime', 'fr_para_hydroxylation', 
                'fr_phenol', 'fr_phenol_noOrthoHbond', 'fr_piperdine', 'fr_piperzine', 'fr_quatN', 
                'fr_sulfide']
numeric_features = [ 'MaxAbsEStateIndex', 'MaxEStateIndex', 
                    'MinAbsEStateIndex', 'MinEStateIndex', 'qed', 'SPS', 'MolWt', 
                    'HeavyAtomMolWt', 'ExactMolWt', 'NumValenceElectrons', 'MaxPartialCharge',
                    'MinPartialCharge', 'MaxAbsPartialCharge', 'MinAbsPartialCharge', 
                    'FpDensityMorgan1', 'FpDensityMorgan2', 'FpDensityMorgan3', 'BCUT2D_MWHI',
                    'BCUT2D_MWLOW', 'BCUT2D_CHGHI', 'BCUT2D_CHGLO', 'BCUT2D_LOGPHI', 
                    'BCUT2D_LOGPLOW', 'BCUT2D_MRHI', 'BCUT2D_MRLOW', 'AvgIpc', 'BalabanJ',
                    'BertzCT', 'Chi0', 'Chi0n', 'Chi0v', 'Chi1', 'Chi1n', 'Chi1v', 'Chi2n',
                    'Chi2v', 'Chi3n', 'Chi3v', 'Chi4n', 'Chi4v', 'HallKierAlpha', 'Ipc', 
                    'Kappa1', 'Kappa2', 'Kappa3', 'LabuteASA', 'PEOE_VSA1', 'PEOE_VSA10',
                    'PEOE_VSA11', 'PEOE_VSA12', 'PEOE_VSA13', 'PEOE_VSA14', 'PEOE_VSA2', 
                    'PEOE_VSA3', 'PEOE_VSA4', 'PEOE_VSA5', 'PEOE_VSA6', 'PEOE_VSA7', 
                    'PEOE_VSA8', 'PEOE_VSA9', 'SMR_VSA1', 'SMR_VSA10', 'SMR_VSA3', 'SMR_VSA4',
                    'SMR_VSA5', 'SMR_VSA6', 'SMR_VSA7', 'SMR_VSA9', 'SlogP_VSA1', 'SlogP_VSA10',
                    'SlogP_VSA11', 'SlogP_VSA12', 'SlogP_VSA2', 'SlogP_VSA3', 'SlogP_VSA4', 
                    'SlogP_VSA5', 'SlogP_VSA6', 'SlogP_VSA8', 'TPSA', 'EState_VSA1', 'EState_VSA10',
                    'EState_VSA2', 'EState_VSA3', 'EState_VSA4', 'EState_VSA5', 'EState_VSA6',
                    'EState_VSA7', 'EState_VSA8', 'EState_VSA9', 'VSA_EState1', 'VSA_EState10',
                    'VSA_EState2', 'VSA_EState3', 'VSA_EState4', 'VSA_EState5', 'VSA_EState6',
                    'VSA_EState7', 'VSA_EState8', 'VSA_EState9', 'FractionCSP3', 'HeavyAtomCount',
                    'NHOHCount', 'NOCount', 'NumHAcceptors', 'NumHDonors', 'NumHeteroatoms', 
                    'NumRotatableBonds', 'MolLogP', 'MolMR', 'fr_NH0', 'fr_unbrch_alkane']
bool_features = ['fr_Al_COO', 'fr_Ar_COO', 'fr_Ar_NH', 'fr_COO', 'fr_COO2', 'fr_C_S', 'fr_HOCCN', 
                 'fr_Nhpyrrole', 'fr_aldehyde', 'fr_alkyl_carbamate', 'fr_amidine', 'fr_azo', 
                 'fr_guanido', 'fr_hdrzine', 'fr_imidazole', 'fr_imide', 'fr_nitrile', 'fr_nitro',
                 'fr_nitro_arom', 'fr_nitro_arom_nonortho', 'fr_oxazole', 'fr_priamide', 
                 'fr_pyridine', 'fr_sulfonamd', 'fr_sulfone', 'fr_term_acetylene', 'fr_tetrazole',
                 'fr_thiazole', 'fr_thiophene', 'fr_urea']

# %%
# Резделение выборки
y = np.log1p(df['IC50, mM'])
X = df.drop(['IC50, mM','CC50, mM', 'SI', 'Unnamed: 0'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=0.15, random_state=62025)

# %%
X_train.columns
# Out:
# Index(['MaxAbsEStateIndex', 'MaxEStateIndex', 'MinAbsEStateIndex',
#        'MinEStateIndex', 'qed', 'SPS', 'MolWt', 'HeavyAtomMolWt', 'ExactMolWt',
#        'NumValenceElectrons',
#        ...
#        'Polar_Groups_Count', 'Lipophilic_Groups_Count', 'PLB',
#        'HBond_Capacity', 'HBond_Donor_Acceptor_Ratio', 'Saturation_Index',
#        'Hydrophobic_VSA', 'BCUT_Electronic', 'Size_Flexibility', 'LogD'],
#       dtype='object', length=209)

# %%
# Создаем копии данных для обработки
X_train_processed = X_train.copy()
X_test_processed = X_test.copy()

# Преобразование типов данных
X_train_processed[cat_features] = X_train_processed[cat_features].astype('category')
X_test_processed[cat_features] = X_test_processed[cat_features].astype('category')

# Исправление: Преобразование bool в int (0/1) ДО масштабирования
X_train_processed[bool_features] = X_train_processed[bool_features].astype(int)
X_test_processed[bool_features] = X_test_processed[bool_features].astype(int)

# Масштабирование только числовых признаков
scaler = StandardScaler()
X_train_processed[numeric_features] = scaler.fit_transform(X_train_processed[numeric_features])
X_test_processed[numeric_features] = scaler.transform(X_test_processed[numeric_features])

# %%
# Создание модели
model = CatBoostRegressor(
    cat_features=cat_features,
    task_type="GPU", 
    devices='0-3',
    loss_function='RMSE',
    verbose=50
    
)

# %%
# Создание модели
# Сетка параметров для поиска
param_grid = {
    'iterations': [100, 150, 200],
    'depth': [4, 6, 8],
    'learning_rate': [0.1, 0.05, 0.5],
    'l2_leaf_reg': [1, 3, 5]
}

# %%
# Пользовательская метрика RMSE
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Настройка GridSearchCV
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=5,
    #n_jobs=-1
)

# %%
# Обучение модели
grid_search.fit(X_train_processed, y_train)
# Out:
# 0:	learn: 1.7387710	total: 8.9ms	remaining: 881ms
# 50:	learn: 1.1170742	total: 318ms	remaining: 305ms
# 99:	learn: 0.9765024	total: 622ms	remaining: 0us
# 0:	learn: 1.7903674	total: 5.98ms	remaining: 592ms
# 50:	learn: 1.0893707	total: 270ms	remaining: 259ms
# 99:	learn: 0.9239640	total: 524ms	remaining: 0us
# 0:	learn: 1.7890548	total: 5.45ms	remaining: 539ms
# 50:	learn: 1.1149904	total: 246ms	remaining: 236ms
# 99:	learn: 0.9394524	total: 485ms	remaining: 0us
# 0:	learn: 1.7620951	total: 5.53ms	remaining: 548ms
# 50:	learn: 1.2482133	total: 244ms	remaining: 235ms
# 99:	learn: 1.1235711	total: 484ms	remaining: 0us
# 0:	learn: 1.8186979	total: 5.59ms	remaining: 554ms
# 50:	learn: 1.2372264	total: 254ms	remaining: 244ms
# 0:	learn: 1.8181469	total: 47ms	remaining: 9.36s
# 50:	learn: 1.2359082	total: 2.5s	remaining: 7.3s
# 100:	learn: 1.0946174	total: 4.95s	remaining: 4.85s
# 150:	learn: 0.9982208	total: 7.35s	remaining: 2.38s
# 199:	learn: 0.9199310	total: 9.76s	remaining: 0us
# 0:	learn: 1.8110129	total: 52.9ms	remaining: 10.5s
# 50:	learn: 1.2704113	total: 2.74s	remaining: 8.01s
# 100:	learn: 1.1133178	total: 5.46s	remaining: 5.35s
# 150:	learn: 1.0070697	total: 8.19s	remaining: 2.66s
# 199:	learn: 0.9297166	total: 10.9s	remaining: 0us
# 0:	learn: 1.5749254	total: 66.9ms	remaining: 13.3s
# 50:	learn: 0.7550373	total: 2.68s	remaining: 7.84s
# 100:	learn: 0.5566643	total: 5.31s	remaining: 5.21s
# 150:	learn: 0.4514751	total: 7.91s	remaining: 2.57s
# 199:	learn: 0.3812088	total: 10.5s	remaining: 0us
# 0:	learn: 1.6018071	total: 52.1ms	remaining: 10.4s
# 50:	learn: 0.7244284	total: 2.48s	remaining: 7.23s
# 100:	learn: 0.5316512	total: 5.02s	remaining: 4.92s
# 150:	learn: 0.4489213	total: 7.52s	remaining: 2.44s
# 199:	learn: 0.3876136	total: 9.91s	remaining: 0us
# 0:	learn: 1.6272229	total: 55.4ms	remaining: 11s
# 50:	learn: 0.6821489	total: 2.72s	remaining: 7.94s
# 100:	learn: 0.4877354	total: 5.48s	remaining: 5.37s
# 150:	learn: 0.3806404	total: 8.15s	remaining: 2.64s
# 199:	learn: 0.3250523	total: 10.8s	remaining: 0us
# 0:	learn: 1.7386315	total: 50.3ms	remaining: 10s
# 50:	learn: 1.1536353	total: 2.76s	remaining: 8.07s
# 100:	learn: 1.0331211	total: 5.48s	remaining: 5.37s
# 150:	learn: 0.9327072	total: 8.16s	remaining: 2.65s
# 199:	learn: 0.8588610	total: 10.7s	remaining: 0us
# 0:	learn: 1.7919668	total: 46.3ms	remaining: 9.22s
# 50:	learn: 1.1140238	total: 2.56s	remaining: 7.49s
# 100:	learn: 0.9634166	total: 5.1s	remaining: 5s
# 150:	learn: 0.8765472	total: 7.46s	remaining: 2.42s
# 199:	learn: 0.8000685	total: 9.86s	remaining: 0us
# 0:	learn: 1.7901870	total: 53.8ms	remaining: 10.7s
# 50:	learn: 1.1503709	total: 2.75s	remaining: 8.02s
# 100:	learn: 0.9842658	total: 5.48s	remaining: 5.37s
# 150:	learn: 0.8631425	total: 8.41s	remaining: 2.73s
# 199:	learn: 0.7845073	total: 11.1s	remaining: 0us
# 0:	learn: 1.7620606	total: 80.2ms	remaining: 16s
# 50:	learn: 1.2741771	total: 3s	remaining: 8.76s
# 100:	learn: 1.1532154	total: 5.96s	remaining: 5.85s
# 150:	learn: 1.0687298	total: 8.92s	remaining: 2.89s
# 199:	learn: 1.0071974	total: 11.5s	remaining: 0us
# 0:	learn: 1.8195253	total: 47.9ms	remaining: 9.53s
# 50:	learn: 1.2599989	total: 2.69s	remaining: 7.86s
# 100:	learn: 1.1173350	total: 5.26s	remaining: 5.15s
# 150:	learn: 1.0344969	total: 7.86s	remaining: 2.55s
# 199:	learn: 0.9684123	total: 10.4s	remaining: 0us
# 0:	learn: 1.8129583	total: 51.5ms	remaining: 10.3s
# 50:	learn: 1.2902786	total: 2.69s	remaining: 7.87s
# 100:	learn: 1.1453668	total: 5.37s	remaining: 5.27s
# 150:	learn: 1.0513469	total: 8.1s	remaining: 2.63s
# 199:	learn: 0.9759076	total: 10.7s	remaining: 0us
# 0:	learn: 1.5847471	total: 58.3ms	remaining: 11.6s
# 50:	learn: 0.8048731	total: 2.84s	remaining: 8.3s
# 100:	learn: 0.6269519	total: 5.66s	remaining: 5.55s
# 150:	learn: 0.5367316	total: 8.24s	remaining: 2.67s
# 199:	learn: 0.4717365	total: 10.8s	remaining: 0us
# 0:	learn: 1.6108232	total: 45.6ms	remaining: 9.08s
# 50:	learn: 0.7835706	total: 2.5s	remaining: 7.3s
# 100:	learn: 0.6115255	total: 5.07s	remaining: 4.97s
# 150:	learn: 0.5126876	total: 7.51s	remaining: 2.44s
# 199:	learn: 0.4508519	total: 9.87s	remaining: 0us
# 0:	learn: 1.6397528	total: 49.4ms	remaining: 9.83s
# 50:	learn: 0.7251237	total: 2.7s	remaining: 7.89s
# 100:	learn: 0.5409769	total: 5.34s	remaining: 5.23s
# 150:	learn: 0.4367459	total: 7.94s	remaining: 2.58s
# 199:	learn: 0.3691446	total: 10.6s	remaining: 0us
# 0:	learn: 1.7410948	total: 52.5ms	remaining: 10.4s
# 50:	learn: 1.1769740	total: 2.65s	remaining: 7.74s
# 100:	learn: 1.0593218	total: 5.32s	remaining: 5.21s
# 150:	learn: 0.9689902	total: 7.9s	remaining: 2.56s
# 199:	learn: 0.9025731	total: 10.4s	remaining: 0us
# 0:	learn: 1.7942088	total: 47.4ms	remaining: 9.43s
# 50:	learn: 1.1445797	total: 2.58s	remaining: 7.54s
# 100:	learn: 1.0045068	total: 5.04s	remaining: 4.94s
# 150:	learn: 0.9160252	total: 7.51s	remaining: 2.44s
# 199:	learn: 0.8427767	total: 10.1s	remaining: 0us
# 0:	learn: 1.7932562	total: 51.5ms	remaining: 10.2s
# 50:	learn: 1.1642673	total: 2.63s	remaining: 7.69s
# 100:	learn: 1.0097795	total: 5.38s	remaining: 5.27s
# 150:	learn: 0.9042042	total: 8.17s	remaining: 2.65s
# 199:	learn: 0.8313230	total: 10.8s	remaining: 0us
# 0:	learn: 1.7633315	total: 48.1ms	remaining: 9.58s
# 50:	learn: 1.2929524	total: 2.69s	remaining: 7.86s
# 100:	learn: 1.1711714	total: 5.31s	remaining: 5.21s
# 150:	learn: 1.0962493	total: 7.87s	remaining: 2.55s
# 199:	learn: 1.0387621	total: 10.4s	remaining: 0us
# 0:	learn: 1.8206811	total: 45.3ms	remaining: 9.02s
# 50:	learn: 1.2772212	total: 2.64s	remaining: 7.72s
# 100:	learn: 1.1351222	total: 5.01s	remaining: 4.92s
# 150:	learn: 1.0529766	total: 7.34s	remaining: 2.38s
# 150:	learn: 0.3579861	total: 12.9s	remaining: 4.2s
# 199:	learn: 0.3004029	total: 17.2s	remaining: 0us
# 0:	learn: 1.5339793	total: 76.5ms	remaining: 15.2s
# 50:	learn: 0.5694446	total: 4.32s	remaining: 12.6s
# 100:	learn: 0.3794171	total: 8.3s	remaining: 8.13s
# 150:	learn: 0.2786239	total: 12.1s	remaining: 3.94s
# 199:	learn: 0.2325425	total: 15.9s	remaining: 0us
# 0:	learn: 1.5564325	total: 85.8ms	remaining: 17.1s
# 50:	learn: 0.5389182	total: 4.37s	remaining: 12.8s
# 100:	learn: 0.3484925	total: 8.87s	remaining: 8.69s
# 150:	learn: 0.2535344	total: 13.3s	remaining: 4.33s
# 199:	learn: 0.1986296	total: 17.7s	remaining: 0us
# 0:	learn: 1.7356840	total: 93.5ms	remaining: 18.6s
# 50:	learn: 1.0280922	total: 4.51s	remaining: 13.2s
# 100:	learn: 0.8929971	total: 8.93s	remaining: 8.75s
# 150:	learn: 0.8005758	total: 13.3s	remaining: 4.32s
# 199:	learn: 0.7353493	total: 17.7s	remaining: 0us
# 0:	learn: 1.7834302	total: 84.5ms	remaining: 16.8s
# 50:	learn: 0.9911894	total: 4.24s	remaining: 12.4s
# 100:	learn: 0.8388004	total: 8.32s	remaining: 8.15s
# 150:	learn: 0.7429335	total: 12.4s	remaining: 4.01s
# 199:	learn: 0.6688838	total: 16.2s	remaining: 0us
# 0:	learn: 1.7796793	total: 92.9ms	remaining: 18.5s
# 50:	learn: 1.0236222	total: 4.58s	remaining: 13.4s
# 100:	learn: 0.8384711	total: 8.91s	remaining: 8.73s
# 150:	learn: 0.7197415	total: 13.3s	remaining: 4.32s
# 199:	learn: 0.6398842	total: 17.6s	remaining: 0us
# 0:	learn: 1.7606930	total: 86.5ms	remaining: 17.2s
# 50:	learn: 1.1896286	total: 4.36s	remaining: 12.7s
# 100:	learn: 1.0342839	total: 8.84s	remaining: 8.66s
# 150:	learn: 0.9494688	total: 13.2s	remaining: 4.27s
# 199:	learn: 0.8818615	total: 17.4s	remaining: 0us
# 0:	learn: 1.8153637	total: 77.6ms	remaining: 15.4s
# 50:	learn: 1.1691803	total: 4.14s	remaining: 12.1s
# 100:	learn: 1.0049182	total: 8.15s	remaining: 7.99s
# 150:	learn: 0.9058817	total: 12.1s	remaining: 3.93s
# 199:	learn: 0.8366978	total: 16.1s	remaining: 0us
# 0:	learn: 1.8077666	total: 88.9ms	remaining: 17.7s
# 50:	learn: 1.1887667	total: 4.63s	remaining: 13.5s
# 100:	learn: 1.0229843	total: 9.15s	remaining: 8.97s
# 150:	learn: 0.9109491	total: 13.5s	remaining: 4.38s
# 199:	learn: 0.8383027	total: 17.7s	remaining: 0us
# 0:	learn: 1.5607770	total: 82.5ms	remaining: 16.4s
# 50:	learn: 0.6605814	total: 4.39s	remaining: 12.8s
# 100:	learn: 0.4785774	total: 8.7s	remaining: 8.52s
# 150:	learn: 0.3723851	total: 13s	remaining: 4.22s
# 199:	learn: 0.3111554	total: 17.1s	remaining: 0us
# 0:	learn: 1.5592945	total: 88.6ms	remaining: 17.6s
# 50:	learn: 0.6439445	total: 4.22s	remaining: 12.3s
# 100:	learn: 0.4440787	total: 8.17s	remaining: 8.01s
# 150:	learn: 0.3382839	total: 12.2s	remaining: 3.95s
# 199:	learn: 0.2728660	total: 16s	remaining: 0us
# 0:	learn: 1.5826026	total: 84.3ms	remaining: 16.8s
# 50:	learn: 0.5902507	total: 4.55s	remaining: 13.3s
# 100:	learn: 0.3965565	total: 9.1s	remaining: 8.92s
# 150:	learn: 0.2976655	total: 13.4s	remaining: 4.35s
# 199:	learn: 0.2359598	total: 17.8s	remaining: 0us
# 0:	learn: 1.7106236	total: 11.7ms	remaining: 1.16s
# 50:	learn: 0.7370748	total: 558ms	remaining: 536ms
# 99:	learn: 0.5853283	total: 1.12s	remaining: 0us
# 0:	learn: 1.7653610	total: 11.9ms	remaining: 1.18s
# 50:	learn: 0.7145292	total: 579ms	remaining: 557ms
# 99:	learn: 0.5170713	total: 1.1s	remaining: 0us
# 0:	learn: 1.7548975	total: 13.3ms	remaining: 1.31s
# 50:	learn: 0.6986609	total: 603ms	remaining: 579ms
# 99:	learn: 0.4897942	total: 1.16s	remaining: 0us
# 0:	learn: 1.7480500	total: 15.3ms	remaining: 1.52s
# 50:	learn: 0.9226991	total: 608ms	remaining: 584ms
# 99:	learn: 0.7348764	total: 1.18s	remaining: 0us
# 0:	learn: 1.8062185	total: 11.6ms	remaining: 1.15s
# 50:	learn: 0.9103281	total: 608ms	remaining: 584ms
# 99:	learn: 0.7054485	total: 1.18s	remaining: 0us
# 0:	learn: 1.7953076	total: 13.2ms	remaining: 1.3s
# 50:	learn: 0.9240274	total: 619ms	remaining: 595ms
# 99:	learn: 0.7111764	total: 1.18s	remaining: 0us
# 0:	learn: 1.4486000	total: 11.4ms	remaining: 1.13s
# 50:	learn: 0.3584230	total: 566ms	remaining: 544ms
# 99:	learn: 0.2158999	total: 1.09s	remaining: 0us
# 0:	learn: 1.4817012	total: 10.9ms	remaining: 1.08s
# 50:	learn: 0.3277253	total: 577ms	remaining: 555ms
# 99:	learn: 0.1885141	total: 1.12s	remaining: 0us
# 0:	learn: 1.4677145	total: 12.5ms	remaining: 1.23s
# 50:	learn: 0.2682490	total: 545ms	remaining: 524ms
# 99:	learn: 0.1438092	total: 1.07s	remaining: 0us
# 0:	learn: 1.7274485	total: 12.5ms	remaining: 1.23s
# 50:	learn: 0.8401008	total: 566ms	remaining: 544ms
# 99:	learn: 0.6846794	total: 1.09s	remaining: 0us
# 0:	learn: 1.7767086	total: 11.1ms	remaining: 1.1s
# 50:	learn: 0.8199693	total: 613ms	remaining: 589ms
# 99:	learn: 0.6412453	total: 1.18s	remaining: 0us
# 0:	learn: 1.7772137	total: 13.2ms	remaining: 1.3s
# 50:	learn: 0.8273577	total: 583ms	remaining: 560ms
# 99:	learn: 0.6206737	total: 1.15s	remaining: 0us
# 0:	learn: 1.7565959	total: 13.1ms	remaining: 1.29s
# 50:	learn: 1.0277033	total: 594ms	remaining: 571ms
# 99:	learn: 0.8410148	total: 1.2s	remaining: 0us
# 0:	learn: 1.8119848	total: 11.8ms	remaining: 1.17s
# 50:	learn: 1.0266641	total: 574ms	remaining: 552ms
# 99:	learn: 0.8220969	total: 1.12s	remaining: 0us
# 0:	learn: 1.8066181	total: 11.4ms	remaining: 1.13s
# 50:	learn: 1.0377237	total: 586ms	remaining: 563ms
# 99:	learn: 0.8139134	total: 1.13s	remaining: 0us
# 0:	learn: 1.5183699	total: 12.6ms	remaining: 1.25s
# 50:	learn: 0.4638177	total: 592ms	remaining: 569ms
# 99:	learn: 0.3104818	total: 1.17s	remaining: 0us
# 0:	learn: 1.5280970	total: 12.9ms	remaining: 1.27s
# 50:	learn: 0.4024868	total: 610ms	remaining: 587ms
# 99:	learn: 0.2674013	total: 1.16s	remaining: 0us
# 0:	learn: 1.5627115	total: 12.2ms	remaining: 1.21s
# 50:	learn: 0.3464771	total: 546ms	remaining: 524ms
# 99:	learn: 0.2178339	total: 1.06s	remaining: 0us
# 0:	learn: 1.7369072	total: 10.5ms	remaining: 1.04s
# 50:	learn: 0.8993213	total: 545ms	remaining: 524ms
# 99:	learn: 0.7569600	total: 1.07s	remaining: 0us
# 0:	learn: 1.7869422	total: 11.2ms	remaining: 1.11s
# 50:	learn: 0.8728206	total: 553ms	remaining: 531ms
# 99:	learn: 0.7022709	total: 1.09s	remaining: 0us
# 0:	learn: 1.7855810	total: 12.2ms	remaining: 1.21s
# 50:	learn: 0.8827294	total: 570ms	remaining: 547ms
# 99:	learn: 0.6988051	total: 1.11s	remaining: 0us
# 0:	learn: 1.7613900	total: 12.2ms	remaining: 1.21s
# 50:	learn: 1.1093150	total: 563ms	remaining: 541ms
# 99:	learn: 0.9177169	total: 1.08s	remaining: 0us
# 0:	learn: 1.8172198	total: 11.6ms	remaining: 1.15s
# 50:	learn: 1.0884515	total: 559ms	remaining: 537ms
# 99:	learn: 0.8898948	total: 1.1s	remaining: 0us
# 0:	learn: 1.8108666	total: 12.3ms	remaining: 1.22s
# 50:	learn: 1.1150953	total: 577ms	remaining: 554ms
# 99:	learn: 0.8902816	total: 1.12s	remaining: 0us
# 0:	learn: 1.5590988	total: 11.7ms	remaining: 1.16s
# 50:	learn: 0.5513797	total: 565ms	remaining: 543ms
# 99:	learn: 0.3950179	total: 1.06s	remaining: 0us
# 0:	learn: 1.5672531	total: 11.4ms	remaining: 1.13s
# 50:	learn: 0.4663280	total: 568ms	remaining: 546ms
# 99:	learn: 0.3024134	total: 1.09s	remaining: 0us
# 0:	learn: 1.5981376	total: 12.4ms	remaining: 1.22s
# 50:	learn: 0.4321822	total: 554ms	remaining: 532ms
# 99:	learn: 0.2677347	total: 1.08s	remaining: 0us
# 0:	learn: 1.7106236	total: 11.3ms	remaining: 1.68s
# 50:	learn: 0.7370748	total: 567ms	remaining: 1.1s
# 100:	learn: 0.5839289	total: 1.11s	remaining: 538ms
# 149:	learn: 0.4919092	total: 1.64s	remaining: 0us
# 0:	learn: 1.7653610	total: 13.7ms	remaining: 2.04s
# 50:	learn: 0.7145292	total: 586ms	remaining: 1.14s
# 100:	learn: 0.5110253	total: 1.13s	remaining: 549ms
# 149:	learn: 0.4089779	total: 1.65s	remaining: 0us
# 0:	learn: 1.7548975	total: 12.6ms	remaining: 1.87s
# 50:	learn: 0.6986609	total: 568ms	remaining: 1.1s
# 100:	learn: 0.4847763	total: 1.11s	remaining: 540ms
# 149:	learn: 0.3616101	total: 1.67s	remaining: 0us
# 0:	learn: 1.7480500	total: 11.7ms	remaining: 1.74s
# 50:	learn: 0.9226991	total: 573ms	remaining: 1.11s
# 100:	learn: 0.7321660	total: 1.13s	remaining: 549ms
# 149:	learn: 0.6376058	total: 1.67s	remaining: 0us
# 0:	learn: 1.8062185	total: 12.7ms	remaining: 1.89s
# 50:	learn: 0.9103281	total: 568ms	remaining: 1.1s
# 100:	learn: 0.7021664	total: 1.12s	remaining: 544ms
# 149:	learn: 0.5952281	total: 1.67s	remaining: 0us
# 0:	learn: 1.7953076	total: 12.4ms	remaining: 1.85s
# 50:	learn: 0.9240274	total: 586ms	remaining: 1.14s
# 100:	learn: 0.7083584	total: 1.14s	remaining: 555ms
# 149:	learn: 0.5826138	total: 1.68s	remaining: 0us
# 0:	learn: 1.4486000	total: 12ms	remaining: 1.79s
# 50:	learn: 0.3584230	total: 567ms	remaining: 1.1s
# 100:	learn: 0.2156715	total: 1.17s	remaining: 569ms
# 149:	learn: 0.1450172	total: 1.75s	remaining: 0us
# 0:	learn: 1.4817012	total: 12.6ms	remaining: 1.88s
# 50:	learn: 0.3277253	total: 556ms	remaining: 1.08s
# 100:	learn: 0.1880970	total: 1.1s	remaining: 533ms
# 149:	learn: 0.1530854	total: 1.69s	remaining: 0us
# 0:	learn: 1.4677145	total: 11.8ms	remaining: 1.75s
# 50:	learn: 0.2682490	total: 556ms	remaining: 1.08s
# 100:	learn: 0.1426522	total: 1.09s	remaining: 530ms
# 149:	learn: 0.0966910	total: 1.64s	remaining: 0us
# 0:	learn: 1.7274485	total: 12.2ms	remaining: 1.82s
# 50:	learn: 0.8401008	total: 603ms	remaining: 1.17s
# 100:	learn: 0.6823744	total: 1.16s	remaining: 564ms
# 149:	learn: 0.5888612	total: 1.78s	remaining: 0us
# 0:	learn: 1.7767086	total: 15ms	remaining: 2.24s
# 50:	learn: 0.8199693	total: 643ms	remaining: 1.25s
# 100:	learn: 0.6371211	total: 1.26s	remaining: 610ms
# 149:	learn: 0.5260021	total: 1.86s	remaining: 0us
# 0:	learn: 1.7772137	total: 12.1ms	remaining: 1.81s
# 50:	learn: 0.8273577	total: 578ms	remaining: 1.12s
# 100:	learn: 0.6162715	total: 1.14s	remaining: 551ms
# 149:	learn: 0.4961466	total: 1.67s	remaining: 0us
# 0:	learn: 1.7565959	total: 11.1ms	remaining: 1.65s
# 50:	learn: 1.0277033	total: 569ms	remaining: 1.1s
# 100:	learn: 0.8394881	total: 1.12s	remaining: 542ms
# 149:	learn: 0.7487240	total: 1.64s	remaining: 0us
# 0:	learn: 1.8119848	total: 11.8ms	remaining: 1.75s
# 50:	learn: 1.0266641	total: 594ms	remaining: 1.15s
# 100:	learn: 0.8180007	total: 1.13s	remaining: 550ms
# 149:	learn: 0.6966924	total: 1.66s	remaining: 0us
# 0:	learn: 1.8066181	total: 13.6ms	remaining: 2.02s
# 50:	learn: 1.0377237	total: 577ms	remaining: 1.12s
# 100:	learn: 0.8107017	total: 1.11s	remaining: 538ms
# 149:	learn: 0.6951913	total: 1.65s	remaining: 0us
# 0:	learn: 1.5183699	total: 11.2ms	remaining: 1.66s
# 50:	learn: 0.4638177	total: 555ms	remaining: 1.08s
# 100:	learn: 0.3092059	total: 1.1s	remaining: 535ms
# 149:	learn: 0.2472737	total: 1.65s	remaining: 0us
# 0:	learn: 1.5280970	total: 10.8ms	remaining: 1.61s
# 50:	learn: 0.4024868	total: 532ms	remaining: 1.03s
# 100:	learn: 0.2668213	total: 1.03s	remaining: 502ms
# 149:	learn: 0.2128134	total: 1.54s	remaining: 0us
# 0:	learn: 1.5627115	total: 11.9ms	remaining: 1.78s
# 50:	learn: 0.3464771	total: 528ms	remaining: 1.02s
# 100:	learn: 0.2161784	total: 1.05s	remaining: 508ms
# 149:	learn: 0.1509029	total: 1.61s	remaining: 0us
# 0:	learn: 1.7369072	total: 11.1ms	remaining: 1.65s
# 50:	learn: 0.8993213	total: 543ms	remaining: 1.05s
# 100:	learn: 0.7546168	total: 1.06s	remaining: 513ms
# 149:	learn: 0.6643447	total: 1.56s	remaining: 0us
# 0:	learn: 1.7869422	total: 13.2ms	remaining: 1.97s
# 50:	learn: 0.8728206	total: 553ms	remaining: 1.07s
# 100:	learn: 0.6998648	total: 1.07s	remaining: 521ms
# 149:	learn: 0.5881259	total: 1.58s	remaining: 0us
# 0:	learn: 1.7855810	total: 11.7ms	remaining: 1.75s
# 50:	learn: 0.8827294	total: 539ms	remaining: 1.05s
# 100:	learn: 0.6963148	total: 1.05s	remaining: 508ms
# 149:	learn: 0.5740800	total: 1.56s	remaining: 0us
# 0:	learn: 1.7613900	total: 11ms	remaining: 1.63s
# 50:	learn: 1.1093150	total: 552ms	remaining: 1.07s
# 100:	learn: 0.9164051	total: 1.08s	remaining: 524ms
# 149:	learn: 0.8227300	total: 1.6s	remaining: 0us
# 0:	learn: 1.8172198	total: 10.9ms	remaining: 1.63s
# 50:	learn: 1.0884515	total: 543ms	remaining: 1.05s
# 100:	learn: 0.8859904	total: 1.11s	remaining: 538ms
# 149:	learn: 0.7766243	total: 1.64s	remaining: 0us
# 0:	learn: 1.8108666	total: 11.6ms	remaining: 1.72s
# 50:	learn: 1.1150953	total: 549ms	remaining: 1.07s
# 100:	learn: 0.8866299	total: 1.08s	remaining: 524ms
# 149:	learn: 0.7695391	total: 1.59s	remaining: 0us
# 0:	learn: 1.5590988	total: 11ms	remaining: 1.64s
# 50:	learn: 0.5513797	total: 521ms	remaining: 1.01s
# 100:	learn: 0.3939001	total: 1.05s	remaining: 510ms
# 149:	learn: 0.2986316	total: 1.57s	remaining: 0us
# 0:	learn: 1.5672531	total: 12.3ms	remaining: 1.83s
# 50:	learn: 0.4663280	total: 555ms	remaining: 1.08s
# 100:	learn: 0.3021382	total: 1.1s	remaining: 533ms
# 149:	learn: 0.2254148	total: 1.63s	remaining: 0us
# 0:	learn: 1.5981376	total: 13.3ms	remaining: 1.98s
# 50:	learn: 0.4321822	total: 535ms	remaining: 1.04s
# 100:	learn: 0.2654238	total: 1.08s	remaining: 522ms
# 149:	learn: 0.1793114	total: 1.6s	remaining: 0us
# 0:	learn: 1.7086565	total: 156ms	remaining: 31s
# 50:	learn: 0.7343294	total: 6.63s	remaining: 19.4s
# 100:	learn: 0.5593714	total: 12.8s	remaining: 12.5s
# 150:	learn: 0.4585577	total: 18.7s	remaining: 6.06s
# 199:	learn: 0.3736647	total: 24.4s	remaining: 0us
# 0:	learn: 1.7546088	total: 119ms	remaining: 23.6s
# 50:	learn: 0.7108480	total: 5.89s	remaining: 17.2s
# 100:	learn: 0.5066241	total: 11.5s	remaining: 11.3s
# 150:	learn: 0.3802869	total: 17.1s	remaining: 5.56s
# 199:	learn: 0.3076527	total: 22.5s	remaining: 0us
# 0:	learn: 1.7570765	total: 125ms	remaining: 24.9s
# 50:	learn: 0.7050319	total: 6.46s	remaining: 18.9s
# 100:	learn: 0.4797866	total: 12.7s	remaining: 12.5s
# 150:	learn: 0.3446822	total: 18.7s	remaining: 6.08s
# 199:	learn: 0.2745978	total: 24.5s	remaining: 0us
# 0:	learn: 1.7470675	total: 119ms	remaining: 23.6s
# 50:	learn: 0.9414903	total: 6.34s	remaining: 18.5s
# 100:	learn: 0.7540377	total: 12.4s	remaining: 12.1s
# 150:	learn: 0.6477148	total: 18.3s	remaining: 5.94s
# 199:	learn: 0.5674645	total: 24.2s	remaining: 0us
# 0:	learn: 1.8008697	total: 109ms	remaining: 21.7s
# 50:	learn: 0.9306382	total: 5.9s	remaining: 17.3s
# 100:	learn: 0.7164318	total: 11.7s	remaining: 11.5s
# 150:	learn: 0.5865652	total: 17.4s	remaining: 5.65s
# 199:	learn: 0.5013039	total: 23s	remaining: 0us
# 0:	learn: 1.7963780	total: 126ms	remaining: 25.2s
# 50:	learn: 0.9175758	total: 6.64s	remaining: 19.4s
# 100:	learn: 0.6868573	total: 13.3s	remaining: 13s
# 150:	learn: 0.5529841	total: 19.5s	remaining: 6.32s
# 199:	learn: 0.4599369	total: 25.7s	remaining: 0us
# 0:	learn: 1.4389161	total: 133ms	remaining: 26.4s
# 50:	learn: 0.3325728	total: 6.27s	remaining: 18.3s
# 100:	learn: 0.2060350	total: 12.1s	remaining: 11.8s
# 150:	learn: 0.1157162	total: 17.8s	remaining: 5.77s
# 199:	learn: 0.0787779	total: 23.4s	remaining: 0us
# 0:	learn: 1.4268120	total: 118ms	remaining: 23.4s
# 50:	learn: 0.2902883	total: 5.76s	remaining: 16.8s
# 100:	learn: 0.1302888	total: 11.2s	remaining: 10.9s
# 150:	learn: 0.0785837	total: 16.6s	remaining: 5.4s
# 199:	learn: 0.0617603	total: 22s	remaining: 0us
# 0:	learn: 1.4801912	total: 120ms	remaining: 23.9s
# 50:	learn: 0.2699706	total: 6.33s	remaining: 18.5s
# 100:	learn: 0.1219035	total: 12.5s	remaining: 12.2s
# 150:	learn: 0.0805541	total: 18.4s	remaining: 5.97s
# 199:	learn: 0.0561154	total: 24.3s	remaining: 0us
# 0:	learn: 1.7258342	total: 127ms	remaining: 25.2s
# 50:	learn: 0.8476992	total: 6.14s	remaining: 18s
# 100:	learn: 0.6706156	total: 12.2s	remaining: 11.9s
# 150:	learn: 0.5605356	total: 18s	remaining: 5.85s
# 199:	learn: 0.4897605	total: 23.8s	remaining: 0us
# 0:	learn: 1.7732153	total: 110ms	remaining: 22s
# 50:	learn: 0.8177878	total: 5.83s	remaining: 17s
# 100:	learn: 0.6268220	total: 11.5s	remaining: 11.3s
# 150:	learn: 0.5082332	total: 17.2s	remaining: 5.58s
# 199:	learn: 0.4346843	total: 22.6s	remaining: 0us
# 0:	learn: 1.7684912	total: 120ms	remaining: 23.9s
# 50:	learn: 0.8342727	total: 6.4s	remaining: 18.7s
# 100:	learn: 0.6263938	total: 12.6s	remaining: 12.3s
# 150:	learn: 0.4852645	total: 18.6s	remaining: 6.05s
# 199:	learn: 0.3988263	total: 24.7s	remaining: 0us
# 0:	learn: 1.7557858	total: 114ms	remaining: 22.7s
# 50:	learn: 1.0552708	total: 6.26s	remaining: 18.3s
# 100:	learn: 0.8597953	total: 12.3s	remaining: 12.1s
# 150:	learn: 0.7567780	total: 18.5s	remaining: 5.99s
# 199:	learn: 0.6764629	total: 24.6s	remaining: 0us
# 0:	learn: 1.8103110	total: 123ms	remaining: 24.4s
# 50:	learn: 1.0326882	total: 5.88s	remaining: 17.2s
# 100:	learn: 0.8218960	total: 11.5s	remaining: 11.3s
# 150:	learn: 0.7017818	total: 17s	remaining: 5.51s
# 199:	learn: 0.6159951	total: 22.4s	remaining: 0us
# 0:	learn: 1.8021987	total: 165ms	remaining: 32.9s
# 50:	learn: 1.0475113	total: 6.93s	remaining: 20.2s
# 100:	learn: 0.8253586	total: 13.8s	remaining: 13.5s
# 150:	learn: 0.6936331	total: 20.5s	remaining: 6.64s
# 199:	learn: 0.6026734	total: 26.8s	remaining: 0us
# 0:	learn: 1.5107010	total: 119ms	remaining: 23.7s
# 50:	learn: 0.4548505	total: 6.55s	remaining: 19.2s
# 100:	learn: 0.2790159	total: 13s	remaining: 12.8s
# 150:	learn: 0.1890699	total: 19.2s	remaining: 6.23s
# 199:	learn: 0.1393109	total: 25.1s	remaining: 0us
# 0:	learn: 1.5040223	total: 116ms	remaining: 23.1s
# 50:	learn: 0.3664248	total: 5.87s	remaining: 17.1s
# 100:	learn: 0.1846240	total: 11.2s	remaining: 11s
# 150:	learn: 0.1198096	total: 16.7s	remaining: 5.4s
# 199:	learn: 0.0887766	total: 22.1s	remaining: 0us
# 0:	learn: 1.5251960	total: 140ms	remaining: 27.9s
# 50:	learn: 0.3636649	total: 6.26s	remaining: 18.3s
# 100:	learn: 0.2012524	total: 12.1s	remaining: 11.9s
# 150:	learn: 0.1282659	total: 18.2s	remaining: 5.9s
# 199:	learn: 0.0986435	total: 23.9s	remaining: 0us
# 0:	learn: 1.7355054	total: 117ms	remaining: 23.4s
# 50:	learn: 0.9067088	total: 6.46s	remaining: 18.9s
# 100:	learn: 0.7479397	total: 12.7s	remaining: 12.4s
# 150:	learn: 0.6372636	total: 18.9s	remaining: 6.14s
# 199:	learn: 0.5613640	total: 25s	remaining: 0us
# 0:	learn: 1.7846501	total: 118ms	remaining: 23.5s
# 50:	learn: 0.8803066	total: 5.84s	remaining: 17.1s
# 100:	learn: 0.6938626	total: 11.6s	remaining: 11.4s
# 150:	learn: 0.5855080	total: 17.3s	remaining: 5.62s
# 199:	learn: 0.5051836	total: 22.7s	remaining: 0us
# 0:	learn: 1.7790728	total: 135ms	remaining: 26.8s
# 50:	learn: 0.8808895	total: 6.52s	remaining: 19.1s
# 100:	learn: 0.6898098	total: 12.8s	remaining: 12.5s
# 150:	learn: 0.5566911	total: 18.8s	remaining: 6.1s
# 199:	learn: 0.4665486	total: 24.8s	remaining: 0us
# 0:	learn: 1.7606885	total: 123ms	remaining: 24.4s
# 50:	learn: 1.1289772	total: 6.26s	remaining: 18.3s
# 100:	learn: 0.9343133	total: 12.4s	remaining: 12.2s
# 150:	learn: 0.8290857	total: 18.7s	remaining: 6.05s
# 199:	learn: 0.7485753	total: 24.5s	remaining: 0us
# 0:	learn: 1.8161022	total: 112ms	remaining: 22.2s
# 50:	learn: 1.1029930	total: 5.79s	remaining: 16.9s
# 100:	learn: 0.8775035	total: 11.6s	remaining: 11.3s
# 150:	learn: 0.7663819	total: 17.3s	remaining: 5.61s
# 199:	learn: 0.6883460	total: 22.8s	remaining: 0us
# 0:	learn: 1.8075556	total: 120ms	remaining: 23.9s
# 50:	learn: 1.1244976	total: 6.43s	remaining: 18.8s
# 100:	learn: 0.8877859	total: 12.8s	remaining: 12.5s
# 150:	learn: 0.7578298	total: 19.3s	remaining: 6.27s
# 199:	learn: 0.6765171	total: 25.4s	remaining: 0us
# 0:	learn: 1.5522337	total: 133ms	remaining: 26.5s
# 50:	learn: 0.5253416	total: 6.52s	remaining: 19s
# 100:	learn: 0.3455387	total: 12.2s	remaining: 12s
# 150:	learn: 0.2582018	total: 18.1s	remaining: 5.88s
# 199:	learn: 0.1930206	total: 23.8s	remaining: 0us
# 0:	learn: 1.5532925	total: 111ms	remaining: 22.1s
# 50:	learn: 0.4600268	total: 5.74s	remaining: 16.8s
# 100:	learn: 0.2662451	total: 11.2s	remaining: 11s
# 150:	learn: 0.1818658	total: 16.9s	remaining: 5.49s
# 199:	learn: 0.1344481	total: 22.2s	remaining: 0us
# 0:	learn: 1.5711502	total: 129ms	remaining: 25.8s
# 50:	learn: 0.4486185	total: 6.29s	remaining: 18.4s
# 100:	learn: 0.2457850	total: 12.2s	remaining: 12s
# 150:	learn: 0.1605373	total: 17.9s	remaining: 5.82s
# 199:	learn: 0.1185084	total: 23.7s	remaining: 0us
# 0:	learn: 1.6253779	total: 55.4ms	remaining: 11s
# 50:	learn: 0.8302777	total: 2.78s	remaining: 8.13s
# 100:	learn: 0.6656190	total: 5.41s	remaining: 5.3s
# 150:	learn: 0.5657926	total: 7.99s	remaining: 2.59s
# 199:	learn: 0.4972830	total: 10.6s	remaining: 0us
# GridSearchCV(cv=3,
#              estimator=<catboost.core.CatBoostRegressor object at 0x0000015BE30CE450>,
#              param_grid={'depth': [4, 6, 8], 'iterations': [100, 150, 200],
#                          'l2_leaf_reg': [1, 3, 5],
#                          'learning_rate': [0.1, 0.05, 0.5]},
#              refit='rmse', return_train_score=True,
#              scoring={'r2': make_scorer(r2_score, response_method='predict'),
#                       'rmse': make_scorer(rmse, response_method='predict')})

# %%
# Лучшая модель
best_model = grid_search.best_estimator_
print("\nЛучшие параметры:", grid_search.best_params_)
print("Лучшая RMSE (кросс-валидация):", grid_search.best_score_)

# Предсказание на тестовом наборе
y_pred = best_model.predict(X_test_processed)
test_rmse = rmse(y_test, y_pred)
test_r2 = r2_score(y_test, y_pred)

print("\nТестовая RMSE:", test_rmse)
print("Тестовый R2:", test_r2)

# Сравнение с baseline
baseline_pred = np.full_like(y_test, y_train.mean())
baseline_rmse = rmse(y_test, baseline_pred)
print("\nBaseline RMSE (предсказание средним):", baseline_rmse)
print("Улучшение над baseline:", round((1 - test_rmse/baseline_rmse)*100, 1), "%")
# Out:
# Лучшие параметры: {'depth': 4, 'iterations': 200, 'l2_leaf_reg': 1, 'learning_rate': 0.5}
# Лучшая RMSE (кросс-валидация): 1.5978124968087748
#
# Тестовая RMSE: 1.3991380988597535
# Тестовый R2: 0.3317579086693747
#
# Baseline RMSE (предсказание средним): 1.718079517963848
# Улучшение над baseline: 18.6 %

# %%
pool = Pool(X_train_processed, y_train, cat_features=cat_features, feature_names=list(X_train_processed.columns))

best_model.plot_tree(
    tree_idx=0,
    pool=pool
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Используемое устройство: {device}")
# Подготовка данных
features = cat_features + numeric_features + bool_features
y = np.log1p(df['IC50, mM'])
X = df[features]

# Разделение выборки
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.15, random_state=62025
)

# Обработка для нейросети

# Создаем преобразователь признаков
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features),
        ('bool', 'passthrough', bool_features)
    ],
    remainder='drop'
)

# Применяем преобразования
X_train_pt = preprocessor.fit_transform(X_train)
X_test_pt = preprocessor.transform(X_test)

# Преобразование в тензоры PyTorch
X_train_tensor = torch.tensor(X_train_pt.astype(np.float32), device=device)
y_train_tensor = torch.tensor(y_train.values.astype(np.float32), device=device)
X_test_tensor = torch.tensor(X_test_pt.astype(np.float32), device=device)
y_test_tensor = torch.tensor(y_test.values.astype(np.float32), device=device)

# Создание DataLoader
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

batch_size = 128
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Определяем размерность входа
input_dim = X_train_pt.shape[1]

# Сама структура сети
class RegressionNN(nn.Module):
    def __init__(self, input_size):
        super(RegressionNN, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 1024),
            nn.ReLU(),
            nn.BatchNorm1d(1024),
            nn.Dropout(0.5),

            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.BatchNorm1d(512),
            nn.Dropout(0.75),

            nn.Linear(512, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.5),

            nn.Linear(256, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Dropout(0.3),

            nn.Linear(128, 64),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Dropout(0.3),
            
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.BatchNorm1d(32),
            nn.Dropout(0.2),
            
            nn.Linear(32, 1)
        )
    
    def forward(self, x):
        return self.layers(x)

# Инициализация модели
model_pt = RegressionNN(input_dim).to(device)

# Функция потерь и оптимизатор
criterion = nn.MSELoss()
optimizer = optim.Adam(model_pt.parameters(), lr=0.01)

# Планировщик скорости обучения
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.9, patience=5, verbose=True
)

# ================================================
# ОБУЧЕНИЕ МОДЕЛИ
# ================================================

num_epochs = 100
best_loss = float('inf')
patience = 15
patience_counter = 0

# Цикл обучения
for epoch in range(num_epochs):
    # Режим обучения
    model_pt.train()
    train_loss = 0.0
    
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        
        # Forward pass
        outputs = model_pt(inputs)
        loss = criterion(outputs, targets.unsqueeze(1))
        
        # Backward pass и оптимизация
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * inputs.size(0)
    
    # Средняя потеря за эпоху
    train_loss /= len(train_loader.dataset)
    
    # Режим оценки
    model_pt.eval()
    val_loss = 0.0
    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model_pt(inputs)
            loss = criterion(outputs, targets.unsqueeze(1))
            val_loss += loss.item() * inputs.size(0)
    
    val_loss /= len(test_loader.dataset)
    scheduler.step(val_loss)
    
    # Вывод статистики
    print(f'Epoch [{epoch+1}/{num_epochs}] | '
          f'Train Loss: {train_loss:.6f} | Val Loss: {val_loss:.6f}')
    # Ранняя остановка
    if val_loss < best_loss:
        best_loss = val_loss
        patience_counter = 0
        # Сохранение лучшей модели
        torch.save(model_pt.state_dict(), 'best_model_pt.pth')
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f'Ранняя остановка на эпохе {epoch+1}')
            break
# Out:
# Используемое устройство: cuda
# Epoch [1/100] | Train Loss: 18.083357 | Val Loss: 14.602341
# D:\jupiter\conda_inst\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [2/100] | Train Loss: 15.736860 | Val Loss: 6.363892
# Epoch [3/100] | Train Loss: 12.677833 | Val Loss: 5.873804
# Epoch [4/100] | Train Loss: 8.557442 | Val Loss: 6.128444
# Epoch [5/100] | Train Loss: 4.806424 | Val Loss: 2.755099
# Epoch [6/100] | Train Loss: 3.402147 | Val Loss: 2.580459
# Epoch [7/100] | Train Loss: 3.465634 | Val Loss: 2.984072
# Epoch [8/100] | Train Loss: 3.072470 | Val Loss: 2.255510
# Epoch [9/100] | Train Loss: 2.636712 | Val Loss: 2.555368
# Epoch [10/100] | Train Loss: 2.607028 | Val Loss: 2.410256
# Epoch [11/100] | Train Loss: 2.524988 | Val Loss: 2.265761
# Epoch [12/100] | Train Loss: 2.370776 | Val Loss: 2.258100
# Epoch [13/100] | Train Loss: 2.383910 | Val Loss: 2.283916
# Epoch [14/100] | Train Loss: 2.283994 | Val Loss: 2.254652
# Epoch [15/100] | Train Loss: 2.253082 | Val Loss: 2.090810
# Epoch [16/100] | Train Loss: 2.227747 | Val Loss: 2.168669
# Epoch [17/100] | Train Loss: 2.121605 | Val Loss: 2.111272
# Epoch [18/100] | Train Loss: 2.101745 | Val Loss: 2.074629
# Epoch [19/100] | Train Loss: 2.194731 | Val Loss: 2.012874
# Epoch [20/100] | Train Loss: 2.021234 | Val Loss: 2.021593
# Epoch [21/100] | Train Loss: 2.016142 | Val Loss: 2.005902
# Epoch [22/100] | Train Loss: 2.009057 | Val Loss: 1.966167
# Epoch [23/100] | Train Loss: 1.961296 | Val Loss: 2.039876
# Epoch [24/100] | Train Loss: 1.878391 | Val Loss: 1.963797
# Epoch [25/100] | Train Loss: 1.979383 | Val Loss: 1.897205
# Epoch [26/100] | Train Loss: 1.894041 | Val Loss: 1.962966
# Epoch [27/100] | Train Loss: 1.786359 | Val Loss: 1.978383
# Epoch [28/100] | Train Loss: 1.663356 | Val Loss: 1.940786
# Epoch [29/100] | Train Loss: 1.716219 | Val Loss: 1.917943
# Epoch [30/100] | Train Loss: 1.680986 | Val Loss: 1.927258
# Epoch [31/100] | Train Loss: 1.664525 | Val Loss: 2.056058
# Epoch [32/100] | Train Loss: 1.697984 | Val Loss: 2.033012
# Epoch [33/100] | Train Loss: 1.661447 | Val Loss: 1.929789
# Epoch [34/100] | Train Loss: 1.682473 | Val Loss: 2.006071
# Epoch [35/100] | Train Loss: 1.620275 | Val Loss: 1.969417
# Epoch [36/100] | Train Loss: 1.633455 | Val Loss: 1.971086
# Epoch [37/100] | Train Loss: 1.620531 | Val Loss: 1.974136
# Epoch [38/100] | Train Loss: 1.541032 | Val Loss: 1.939970
# Epoch [39/100] | Train Loss: 1.586258 | Val Loss: 1.989191
# Epoch [40/100] | Train Loss: 1.614545 | Val Loss: 1.903049
# Ранняя остановка на эпохе 40

# %%
# ОЦЕНКА МОДЕЛИ

def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Предсказание на тестовом наборе
all_preds = []
with torch.no_grad():
    for inputs, _ in test_loader:
        inputs = inputs.to(device)
        outputs = model_pt(inputs)
        all_preds.append(outputs.cpu().numpy())

y_pred_pt = np.concatenate(all_preds).flatten()

# Расчет метрик
test_rmse_pt = rmse(y_test, y_pred_pt)
test_r2_pt = r2_score(y_test, y_pred_pt)

print("\n[PyTorch] Тестовая RMSE:", test_rmse_pt)
print("[PyTorch] Тестовый R2:", test_r2_pt)
# Out:
# [PyTorch] Тестовая RMSE: 1.3795104821170268
# [PyTorch] Тестовый R2: 0.35037508687400376

# %% [markdown]
# # Вывод:
# Лучше в предсказании себя показывает нейронная сеть, она может строить более сложные зависимости, однако выбор отдади модели CAT BOOST из-за возможности интерпретировать результат.
# При этом, качетво моделей не достаточно высокое.
