# %% [markdown]
# # Задачи регрессии CC50, mM

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error, r2_score, make_scorer

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,  FunctionTransformer
from sklearn.pipeline import Pipeline

from catboost import  Pool
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin'

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
# Прочитаем обработанный датасет
df = pd.read_csv('./data_him.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    IC50, mM    CC50, mM         SI  MaxAbsEStateIndex  \
# 0           0    6.239374  175.482382  28.125000           5.094096
# 1           1    0.771831    5.402819   7.000000           3.961417
# 2           2  223.808778  161.142320   0.720000           2.627117
# 3           3    1.705624  107.855654  63.235294           5.097360
# 4           4  107.131532  139.270991   1.300000           5.150510
#
#    MaxEStateIndex  MinAbsEStateIndex  MinEStateIndex       qed        SPS  \
# 0        5.094096           0.387225        0.387225  0.417362  42.928571
# 1        3.961417           0.533868        0.533868  0.462473  45.214286
# 2        2.627117           0.543231        0.543231  0.260923  42.187500
# 3        5.097360           0.390603        0.390603  0.377846  41.862069
# 4        5.150510           0.270476        0.270476  0.429038  36.514286
#
#    ...  Polar_Groups_Count  Lipophilic_Groups_Count  PLB  HBond_Capacity  \
# 0  ...                   0                        3  0.0               2
# 1  ...                   0                        3  0.0               4
# 2  ...                   0                        3  0.0               0
# 3  ...                   0                        4  0.0               2
# 4  ...                   0                        0  0.0               2
#
#    HBond_Donor_Acceptor_Ratio  Saturation_Index  Hydrophobic_VSA  \
# 0                         0.0          1.000000       173.744106
# 1                         1.0          1.000000       175.053185
# 2                         0.0          1.000000       201.576358
# 3                         0.0          1.000000       180.164927
# 4                         0.0          0.666667       201.049968
#
#    BCUT_Electronic  Size_Flexibility    LogD
# 0        38.545778          26.92564  7.1212
# 1        39.145933          34.98156  6.1556
# 2        40.922447          40.21272  7.1292
# 3        38.542997          31.89432  7.5113
# 4        38.597756          18.66852  9.1148
#
# [5 rows x 213 columns]

# %%
df.shape
# Out:
# (970, 213)

# %%
cat_features = ['NumAliphaticCarbocycles', 'NumAliphaticHeterocycles', 'NumAliphaticRings', 
                'NumAromaticCarbocycles', 'NumAromaticHeterocycles', 'NumAromaticRings', 
                'NumSaturatedCarbocycles', 'NumSaturatedHeterocycles', 'NumSaturatedRings',
                'RingCount', 'fr_Al_OH', 'fr_Al_OH_noTert', 'fr_ArN', 'fr_Ar_N', 'fr_Ar_OH',
                'fr_C_O', 'fr_C_O_noCOO', 'fr_Imine', 'fr_NH1', 'fr_NH2', 'fr_Ndealkylation1', 
                'fr_Ndealkylation2', 'fr_alkyl_halide', 'fr_allylic_oxid', 'fr_amide', 'fr_aniline',
                'fr_aryl_methyl', 'fr_benzene', 'fr_bicyclic', 'fr_epoxide', 'fr_ester', 
                'fr_ether', 'fr_furan', 'fr_halogen', 'fr_hdrzone', 'fr_ketone', 'fr_ketone_Topliss',
                'fr_lactone', 'fr_methoxy', 'fr_morpholine', 'fr_oxime', 'fr_para_hydroxylation', 
                'fr_phenol', 'fr_phenol_noOrthoHbond', 'fr_piperdine', 'fr_piperzine', 'fr_quatN', 
                'fr_sulfide']
numeric_features = [ 'MaxAbsEStateIndex', 'MaxEStateIndex', 
                    'MinAbsEStateIndex', 'MinEStateIndex', 'qed', 'SPS', 'MolWt', 
                    'HeavyAtomMolWt', 'ExactMolWt', 'NumValenceElectrons', 'MaxPartialCharge',
                    'MinPartialCharge', 'MaxAbsPartialCharge', 'MinAbsPartialCharge', 
                    'FpDensityMorgan1', 'FpDensityMorgan2', 'FpDensityMorgan3', 'BCUT2D_MWHI',
                    'BCUT2D_MWLOW', 'BCUT2D_CHGHI', 'BCUT2D_CHGLO', 'BCUT2D_LOGPHI', 
                    'BCUT2D_LOGPLOW', 'BCUT2D_MRHI', 'BCUT2D_MRLOW', 'AvgIpc', 'BalabanJ',
                    'BertzCT', 'Chi0', 'Chi0n', 'Chi0v', 'Chi1', 'Chi1n', 'Chi1v', 'Chi2n',
                    'Chi2v', 'Chi3n', 'Chi3v', 'Chi4n', 'Chi4v', 'HallKierAlpha', 'Ipc', 
                    'Kappa1', 'Kappa2', 'Kappa3', 'LabuteASA', 'PEOE_VSA1', 'PEOE_VSA10',
                    'PEOE_VSA11', 'PEOE_VSA12', 'PEOE_VSA13', 'PEOE_VSA14', 'PEOE_VSA2', 
                    'PEOE_VSA3', 'PEOE_VSA4', 'PEOE_VSA5', 'PEOE_VSA6', 'PEOE_VSA7', 
                    'PEOE_VSA8', 'PEOE_VSA9', 'SMR_VSA1', 'SMR_VSA10', 'SMR_VSA3', 'SMR_VSA4',
                    'SMR_VSA5', 'SMR_VSA6', 'SMR_VSA7', 'SMR_VSA9', 'SlogP_VSA1', 'SlogP_VSA10',
                    'SlogP_VSA11', 'SlogP_VSA12', 'SlogP_VSA2', 'SlogP_VSA3', 'SlogP_VSA4', 
                    'SlogP_VSA5', 'SlogP_VSA6', 'SlogP_VSA8', 'TPSA', 'EState_VSA1', 'EState_VSA10',
                    'EState_VSA2', 'EState_VSA3', 'EState_VSA4', 'EState_VSA5', 'EState_VSA6',
                    'EState_VSA7', 'EState_VSA8', 'EState_VSA9', 'VSA_EState1', 'VSA_EState10',
                    'VSA_EState2', 'VSA_EState3', 'VSA_EState4', 'VSA_EState5', 'VSA_EState6',
                    'VSA_EState7', 'VSA_EState8', 'VSA_EState9', 'FractionCSP3', 'HeavyAtomCount',
                    'NHOHCount', 'NOCount', 'NumHAcceptors', 'NumHDonors', 'NumHeteroatoms', 
                    'NumRotatableBonds', 'MolLogP', 'MolMR', 'fr_NH0', 'fr_unbrch_alkane']
bool_features = ['fr_Al_COO', 'fr_Ar_COO', 'fr_Ar_NH', 'fr_COO', 'fr_COO2', 'fr_C_S', 'fr_HOCCN', 
                 'fr_Nhpyrrole', 'fr_aldehyde', 'fr_alkyl_carbamate', 'fr_amidine', 'fr_azo', 
                 'fr_guanido', 'fr_hdrzine', 'fr_imidazole', 'fr_imide', 'fr_nitrile', 'fr_nitro',
                 'fr_nitro_arom', 'fr_nitro_arom_nonortho', 'fr_oxazole', 'fr_priamide', 
                 'fr_pyridine', 'fr_sulfonamd', 'fr_sulfone', 'fr_term_acetylene', 'fr_tetrazole',
                 'fr_thiazole', 'fr_thiophene', 'fr_urea']

# %%
# Резделение выборки
y = np.log1p(df['CC50, mM'])
X = df.drop(['IC50, mM','CC50, mM', 'SI', 'Unnamed: 0'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=0.15, random_state=62025)

# %%
X_train.columns
# Out:
# Index(['MaxAbsEStateIndex', 'MaxEStateIndex', 'MinAbsEStateIndex',
#        'MinEStateIndex', 'qed', 'SPS', 'MolWt', 'HeavyAtomMolWt', 'ExactMolWt',
#        'NumValenceElectrons',
#        ...
#        'Polar_Groups_Count', 'Lipophilic_Groups_Count', 'PLB',
#        'HBond_Capacity', 'HBond_Donor_Acceptor_Ratio', 'Saturation_Index',
#        'Hydrophobic_VSA', 'BCUT_Electronic', 'Size_Flexibility', 'LogD'],
#       dtype='object', length=209)

# %%
# Создаем копии данных для обработки
X_train_processed = X_train.copy()
X_test_processed = X_test.copy()

# Преобразование типов данных
X_train_processed[cat_features] = X_train_processed[cat_features].astype('category')
X_test_processed[cat_features] = X_test_processed[cat_features].astype('category')

# Исправление: Преобразование bool в int (0/1) ДО масштабирования
X_train_processed[bool_features] = X_train_processed[bool_features].astype(int)
X_test_processed[bool_features] = X_test_processed[bool_features].astype(int)

# Масштабирование только числовых признаков
scaler = StandardScaler()
X_train_processed[numeric_features] = scaler.fit_transform(X_train_processed[numeric_features])
X_test_processed[numeric_features] = scaler.transform(X_test_processed[numeric_features])

# %%
# Создание модели
model = CatBoostRegressor(
    cat_features=cat_features,
    task_type="GPU", 
    devices='0-3',
    loss_function='RMSE',
    verbose=50
    
)

# %%
# Создание модели
# Сетка параметров для поиска
param_grid = {
    'iterations': [100, 150, 300],
    'depth': [2, 4, 6],
    'learning_rate': [0.1, 0.05, 0.5]
}

# %%
# Пользовательская метрика RMSE
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Настройка GridSearchCV
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=3,
    scoring={
        'rmse': make_scorer(rmse),
        'r2': make_scorer(r2_score)
    },
    refit='rmse',
    #n_jobs=-1,
    return_train_score=True
)

# %%
# Обучение модели
grid_search.fit(X_train_processed, y_train)
# Out:
# 0:	learn: 1.5423856	total: 4.17ms	remaining: 413ms
# 50:	learn: 1.1258072	total: 179ms	remaining: 172ms
# 99:	learn: 1.0360782	total: 348ms	remaining: 0us
# 0:	learn: 1.5141218	total: 3.96ms	remaining: 392ms
# 50:	learn: 1.0997125	total: 181ms	remaining: 174ms
# 99:	learn: 0.9917599	total: 361ms	remaining: 0us
# 0:	learn: 1.5517040	total: 4ms	remaining: 396ms
# 50:	learn: 1.1639588	total: 176ms	remaining: 169ms
# 99:	learn: 1.0539421	total: 362ms	remaining: 0us
# 0:	learn: 1.5573985	total: 4.53ms	remaining: 448ms
# 50:	learn: 1.2434800	total: 178ms	remaining: 171ms
# 99:	learn: 1.1394292	total: 357ms	remaining: 0us
# 0:	learn: 1.5281611	total: 3.8ms	remaining: 376ms
# 50:	learn: 1.2151592	total: 170ms	remaining: 163ms
# 99:	learn: 1.0996958	total: 343ms	remaining: 0us
# 0:	learn: 1.5616193	total: 4.28ms	remaining: 424ms
# 50:	learn: 1.2801531	total: 180ms	remaining: 173ms
# 99:	learn: 1.1735308	total: 355ms	remaining: 0us
# 0:	learn: 1.4469417	total: 4.25ms	remaining: 420ms
# 50:	learn: 0.9312556	total: 175ms	remaining: 168ms
# 99:	learn: 0.8363007	total: 350ms	remaining: 0us
# 0:	learn: 1.4251321	total: 4.11ms	remaining: 407ms
# 50:	learn: 0.8877698	total: 172ms	remaining: 166ms
# 99:	learn: 0.7867039	total: 341ms	remaining: 0us
# 0:	learn: 1.4892417	total: 4.38ms	remaining: 434ms
# 50:	learn: 0.9081546	total: 174ms	remaining: 167ms
# 99:	learn: 0.7617287	total: 346ms	remaining: 0us
# 0:	learn: 1.5423856	total: 3.94ms	remaining: 587ms
# 50:	learn: 1.1258072	total: 172ms	remaining: 335ms
# 100:	learn: 1.0339396	total: 344ms	remaining: 167ms
# 149:	learn: 0.9732164	total: 527ms	remaining: 0us
# 0:	learn: 1.5141218	total: 4.08ms	remaining: 608ms
# 50:	learn: 1.0997125	total: 194ms	remaining: 377ms
# 100:	learn: 0.9910627	total: 364ms	remaining: 177ms
# 149:	learn: 0.9361140	total: 536ms	remaining: 0us
# 0:	learn: 1.5517040	total: 4.08ms	remaining: 608ms
# 50:	learn: 1.1639588	total: 185ms	remaining: 360ms
# 100:	learn: 1.0518294	total: 363ms	remaining: 176ms
# 149:	learn: 0.9942332	total: 530ms	remaining: 0us
# 0:	learn: 1.5573985	total: 3.95ms	remaining: 588ms
# 50:	learn: 1.2434800	total: 171ms	remaining: 332ms
# 100:	learn: 1.1386932	total: 343ms	remaining: 166ms
# 149:	learn: 1.0774084	total: 507ms	remaining: 0us
# 0:	learn: 1.5281611	total: 4.75ms	remaining: 707ms
# 50:	learn: 1.2151592	total: 171ms	remaining: 331ms
# 100:	learn: 1.0984738	total: 341ms	remaining: 166ms
# 149:	learn: 1.0346997	total: 508ms	remaining: 0us
# 0:	learn: 1.5616193	total: 4.67ms	remaining: 696ms
# 50:	learn: 1.2801531	total: 176ms	remaining: 341ms
# 100:	learn: 1.1725778	total: 349ms	remaining: 169ms
# 149:	learn: 1.1134870	total: 520ms	remaining: 0us
# 0:	learn: 1.4469417	total: 4.87ms	remaining: 725ms
# 50:	learn: 0.9312556	total: 205ms	remaining: 397ms
# 100:	learn: 0.8345405	total: 443ms	remaining: 215ms
# 149:	learn: 0.7506725	total: 672ms	remaining: 0us
# 0:	learn: 1.4251321	total: 4.52ms	remaining: 674ms
# 50:	learn: 0.8877698	total: 238ms	remaining: 461ms
# 100:	learn: 0.7838509	total: 445ms	remaining: 216ms
# 149:	learn: 0.7123620	total: 640ms	remaining: 0us
# 0:	learn: 1.4892417	total: 4.03ms	remaining: 600ms
# 50:	learn: 0.9081546	total: 228ms	remaining: 443ms
# 100:	learn: 0.7608427	total: 447ms	remaining: 217ms
# 149:	learn: 0.6900000	total: 670ms	remaining: 0us
# 0:	learn: 1.5423856	total: 20.5ms	remaining: 6.14s
# 50:	learn: 1.1388811	total: 1.13s	remaining: 5.52s
# 100:	learn: 1.0327374	total: 2.28s	remaining: 4.49s
# 150:	learn: 0.9763165	total: 3.36s	remaining: 3.32s
# 200:	learn: 0.9385431	total: 4.38s	remaining: 2.16s
# 250:	learn: 0.9041358	total: 5.36s	remaining: 1.05s
# 299:	learn: 0.8745295	total: 6.33s	remaining: 0us
# 0:	learn: 1.5141218	total: 18.5ms	remaining: 5.53s
# 50:	learn: 1.0918706	total: 969ms	remaining: 4.73s
# 100:	learn: 0.9792208	total: 1.86s	remaining: 3.67s
# 150:	learn: 0.9267326	total: 2.87s	remaining: 2.83s
# 200:	learn: 0.8951515	total: 3.86s	remaining: 1.9s
# 250:	learn: 0.8593746	total: 4.79s	remaining: 935ms
# 299:	learn: 0.8355096	total: 5.68s	remaining: 0us
# 0:	learn: 1.5517041	total: 18.7ms	remaining: 5.61s
# 50:	learn: 1.1596396	total: 964ms	remaining: 4.71s
# 100:	learn: 1.0447727	total: 1.9s	remaining: 3.75s
# 150:	learn: 0.9754977	total: 2.89s	remaining: 2.85s
# 200:	learn: 0.9221039	total: 3.83s	remaining: 1.89s
# 250:	learn: 0.8803555	total: 4.84s	remaining: 945ms
# 299:	learn: 0.8510928	total: 5.83s	remaining: 0us
# 0:	learn: 1.5573984	total: 20.1ms	remaining: 6s
# 50:	learn: 1.2414066	total: 1s	remaining: 4.9s
# 100:	learn: 1.1327110	total: 1.99s	remaining: 3.92s
# 150:	learn: 1.0719502	total: 2.93s	remaining: 2.89s
# 200:	learn: 1.0342436	total: 3.89s	remaining: 1.92s
# 250:	learn: 1.0071142	total: 4.88s	remaining: 953ms
# 299:	learn: 0.9804502	total: 5.83s	remaining: 0us
# 0:	learn: 1.5281611	total: 17.4ms	remaining: 5.21s
# 50:	learn: 1.2113083	total: 892ms	remaining: 4.36s
# 100:	learn: 1.0983924	total: 1.76s	remaining: 3.48s
# 150:	learn: 1.0325883	total: 2.64s	remaining: 2.6s
# 200:	learn: 0.9912845	total: 3.49s	remaining: 1.72s
# 250:	learn: 0.9553128	total: 4.36s	remaining: 851ms
# 299:	learn: 0.9327780	total: 5.23s	remaining: 0us
# 0:	learn: 1.5616192	total: 18.5ms	remaining: 5.53s
# 50:	learn: 1.2745127	total: 968ms	remaining: 4.73s
# 100:	learn: 1.1617669	total: 1.96s	remaining: 3.86s
# 150:	learn: 1.1014284	total: 3s	remaining: 2.96s
# 200:	learn: 1.0483467	total: 4.01s	remaining: 1.97s
# 250:	learn: 1.0109390	total: 4.95s	remaining: 966ms
# 299:	learn: 0.9828629	total: 5.86s	remaining: 0us
# 0:	learn: 1.4469418	total: 18.2ms	remaining: 5.45s
# 50:	learn: 0.8882219	total: 947ms	remaining: 4.62s
# 100:	learn: 0.7733072	total: 1.89s	remaining: 3.73s
# 150:	learn: 0.7042258	total: 2.83s	remaining: 2.8s
# 200:	learn: 0.6499377	total: 3.79s	remaining: 1.87s
# 250:	learn: 0.6090459	total: 4.75s	remaining: 928ms
# 299:	learn: 0.5830941	total: 5.67s	remaining: 0us
# 0:	learn: 1.4251321	total: 17.9ms	remaining: 5.34s
# 50:	learn: 0.8502278	total: 907ms	remaining: 4.43s
# 100:	learn: 0.7611105	total: 1.77s	remaining: 3.48s
# 150:	learn: 0.7037109	total: 2.64s	remaining: 2.6s
# 200:	learn: 0.6483729	total: 3.49s	remaining: 1.72s
# 250:	learn: 0.6024849	total: 4.37s	remaining: 852ms
# 299:	learn: 0.5740548	total: 5.22s	remaining: 0us
# 0:	learn: 1.4892417	total: 20.2ms	remaining: 6.05s
# 50:	learn: 0.9075482	total: 967ms	remaining: 4.72s
# 100:	learn: 0.7703155	total: 1.93s	remaining: 3.8s
# 150:	learn: 0.6762924	total: 2.88s	remaining: 2.84s
# 200:	learn: 0.6169248	total: 3.82s	remaining: 1.88s
# 250:	learn: 0.5669462	total: 4.8s	remaining: 937ms
# 299:	learn: 0.5280851	total: 5.79s	remaining: 0us
# 0:	learn: 1.5217727	total: 6.22ms	remaining: 616ms
# 50:	learn: 0.9653713	total: 257ms	remaining: 247ms
# 99:	learn: 0.8600403	total: 502ms	remaining: 0us
# 0:	learn: 1.4951135	total: 6.11ms	remaining: 605ms
# 50:	learn: 0.9566987	total: 279ms	remaining: 268ms
# 99:	learn: 0.8450230	total: 533ms	remaining: 0us
# 0:	learn: 1.5350259	total: 5.91ms	remaining: 585ms
# 50:	learn: 0.9925772	total: 257ms	remaining: 246ms
# 99:	learn: 0.8596363	total: 504ms	remaining: 0us
# 0:	learn: 1.5470138	total: 5.79ms	remaining: 573ms
# 50:	learn: 1.0792674	total: 275ms	remaining: 265ms
# 99:	learn: 0.9827320	total: 520ms	remaining: 0us
# 0:	learn: 1.5185826	total: 5.48ms	remaining: 543ms
# 50:	learn: 1.0664882	total: 256ms	remaining: 246ms
# 99:	learn: 0.9449885	total: 505ms	remaining: 0us
# 0:	learn: 1.5531953	total: 5.71ms	remaining: 565ms
# 50:	learn: 1.1291658	total: 259ms	remaining: 248ms
# 99:	learn: 1.0023617	total: 512ms	remaining: 0us
# 0:	learn: 1.3529150	total: 6.1ms	remaining: 604ms
# 50:	learn: 0.6975869	total: 249ms	remaining: 239ms
# 99:	learn: 0.5342354	total: 495ms	remaining: 0us
# 0:	learn: 1.3385140	total: 6.53ms	remaining: 646ms
# 50:	learn: 0.6776509	total: 254ms	remaining: 244ms
# 99:	learn: 0.5365279	total: 492ms	remaining: 0us
# 0:	learn: 1.4143277	total: 5.47ms	remaining: 542ms
# 50:	learn: 0.6603308	total: 255ms	remaining: 245ms
# 99:	learn: 0.5133458	total: 514ms	remaining: 0us
# 0:	learn: 1.5217727	total: 5.25ms	remaining: 782ms
# 50:	learn: 0.9653713	total: 269ms	remaining: 522ms
# 100:	learn: 0.8587020	total: 515ms	remaining: 250ms
# 149:	learn: 0.7915063	total: 768ms	remaining: 0us
# 0:	learn: 1.4951135	total: 5.57ms	remaining: 830ms
# 50:	learn: 0.9566987	total: 259ms	remaining: 503ms
# 100:	learn: 0.8433356	total: 523ms	remaining: 254ms
# 149:	learn: 0.7687777	total: 774ms	remaining: 0us
# 0:	learn: 1.5350259	total: 8.51ms	remaining: 1.27s
# 50:	learn: 0.9925772	total: 280ms	remaining: 544ms
# 100:	learn: 0.8575509	total: 556ms	remaining: 270ms
# 149:	learn: 0.7688757	total: 826ms	remaining: 0us
# 0:	learn: 1.5470138	total: 5.39ms	remaining: 804ms
# 50:	learn: 1.0792674	total: 263ms	remaining: 510ms
# 100:	learn: 0.9807525	total: 523ms	remaining: 254ms
# 149:	learn: 0.9193842	total: 781ms	remaining: 0us
# 0:	learn: 1.5185826	total: 5.97ms	remaining: 890ms
# 50:	learn: 1.0664882	total: 261ms	remaining: 507ms
# 100:	learn: 0.9433491	total: 516ms	remaining: 250ms
# 149:	learn: 0.8754512	total: 772ms	remaining: 0us
# 0:	learn: 1.5531953	total: 5.24ms	remaining: 781ms
# 50:	learn: 1.1291658	total: 255ms	remaining: 496ms
# 100:	learn: 1.0005609	total: 509ms	remaining: 247ms
# 149:	learn: 0.9224901	total: 775ms	remaining: 0us
# 0:	learn: 1.3529150	total: 6.18ms	remaining: 921ms
# 50:	learn: 0.6975869	total: 254ms	remaining: 493ms
# 100:	learn: 0.5322198	total: 511ms	remaining: 248ms
# 149:	learn: 0.4640907	total: 762ms	remaining: 0us
# 0:	learn: 1.3385140	total: 5.68ms	remaining: 847ms
# 50:	learn: 0.6776509	total: 257ms	remaining: 498ms
# 100:	learn: 0.5335842	total: 515ms	remaining: 250ms
# 149:	learn: 0.4415230	total: 761ms	remaining: 0us
# 0:	learn: 1.4143277	total: 6.03ms	remaining: 898ms
# 50:	learn: 0.6603308	total: 260ms	remaining: 505ms
# 100:	learn: 0.5120535	total: 515ms	remaining: 250ms
# 149:	learn: 0.4230244	total: 768ms	remaining: 0us
# 0:	learn: 1.5262534	total: 49.8ms	remaining: 14.9s
# 50:	learn: 0.9925813	total: 2.6s	remaining: 12.7s
# 100:	learn: 0.8715536	total: 5.21s	remaining: 10.3s
# 150:	learn: 0.7978511	total: 7.83s	remaining: 7.72s
# 200:	learn: 0.7401581	total: 10.4s	remaining: 5.14s
# 250:	learn: 0.6978616	total: 13s	remaining: 2.54s
# 299:	learn: 0.6629591	total: 15.5s	remaining: 0us
# 0:	learn: 1.4951900	total: 45.7ms	remaining: 13.7s
# 50:	learn: 0.9482877	total: 2.44s	remaining: 11.9s
# 100:	learn: 0.8292516	total: 4.86s	remaining: 9.57s
# 150:	learn: 0.7634169	total: 7.23s	remaining: 7.13s
# 200:	learn: 0.7162561	total: 9.64s	remaining: 4.75s
# 250:	learn: 0.6714424	total: 12.1s	remaining: 2.35s
# 299:	learn: 0.6379191	total: 14.4s	remaining: 0us
# 0:	learn: 1.5363354	total: 50.9ms	remaining: 15.2s
# 50:	learn: 0.9866847	total: 2.68s	remaining: 13.1s
# 100:	learn: 0.8404662	total: 5.28s	remaining: 10.4s
# 150:	learn: 0.7517490	total: 7.98s	remaining: 7.87s
# 200:	learn: 0.6863313	total: 10.6s	remaining: 5.23s
# 250:	learn: 0.6363969	total: 13.3s	remaining: 2.6s
# 299:	learn: 0.5942844	total: 15.9s	remaining: 0us
# 0:	learn: 1.5492748	total: 49.2ms	remaining: 14.7s
# 50:	learn: 1.0844922	total: 2.68s	remaining: 13.1s
# 100:	learn: 0.9748691	total: 5.31s	remaining: 10.5s
# 150:	learn: 0.9149630	total: 7.86s	remaining: 7.76s
# 200:	learn: 0.8677591	total: 10.5s	remaining: 5.16s
# 250:	learn: 0.8274316	total: 13s	remaining: 2.54s
# 299:	learn: 0.7980602	total: 15.6s	remaining: 0us
# 0:	learn: 1.5186072	total: 46.6ms	remaining: 13.9s
# 50:	learn: 1.0643059	total: 2.44s	remaining: 11.9s
# 100:	learn: 0.9376403	total: 4.84s	remaining: 9.54s
# 150:	learn: 0.8733766	total: 7.25s	remaining: 7.15s
# 200:	learn: 0.8239254	total: 9.64s	remaining: 4.75s
# 250:	learn: 0.7871560	total: 12.2s	remaining: 2.38s
# 299:	learn: 0.7597412	total: 14.7s	remaining: 0us
# 0:	learn: 1.5538518	total: 49.3ms	remaining: 14.7s
# 50:	learn: 1.1224409	total: 2.71s	remaining: 13.2s
# 100:	learn: 0.9919221	total: 5.35s	remaining: 10.5s
# 150:	learn: 0.9052162	total: 7.97s	remaining: 7.86s
# 200:	learn: 0.8432180	total: 10.6s	remaining: 5.24s
# 250:	learn: 0.7910149	total: 13.3s	remaining: 2.6s
# 299:	learn: 0.7507296	total: 15.9s	remaining: 0us
# 0:	learn: 1.3729285	total: 52.9ms	remaining: 15.8s
# 50:	learn: 0.7373916	total: 2.62s	remaining: 12.8s
# 100:	learn: 0.5626516	total: 5.22s	remaining: 10.3s
# 150:	learn: 0.4748665	total: 7.87s	remaining: 7.77s
# 200:	learn: 0.4243509	total: 10.5s	remaining: 5.18s
# 250:	learn: 0.3941361	total: 13.1s	remaining: 2.56s
# 299:	learn: 0.3566421	total: 15.6s	remaining: 0us
# 0:	learn: 1.3401262	total: 46ms	remaining: 13.7s
# 50:	learn: 0.6786091	total: 2.44s	remaining: 11.9s
# 100:	learn: 0.5389042	total: 4.86s	remaining: 9.57s
# 150:	learn: 0.4510098	total: 7.3s	remaining: 7.21s
# 200:	learn: 0.3937489	total: 9.72s	remaining: 4.79s
# 250:	learn: 0.3377852	total: 12.2s	remaining: 2.38s
# 299:	learn: 0.3080024	total: 14.5s	remaining: 0us
# 0:	learn: 1.4206112	total: 53ms	remaining: 15.8s
# 50:	learn: 0.6648410	total: 2.66s	remaining: 13s
# 100:	learn: 0.5148289	total: 5.26s	remaining: 10.4s
# 150:	learn: 0.4134318	total: 7.88s	remaining: 7.78s
# 200:	learn: 0.3579211	total: 10.5s	remaining: 5.17s
# 250:	learn: 0.3119461	total: 13.2s	remaining: 2.57s
# 299:	learn: 0.2798144	total: 15.8s	remaining: 0us
# 0:	learn: 1.5176762	total: 7.77ms	remaining: 769ms
# 50:	learn: 0.8557802	total: 368ms	remaining: 354ms
# 99:	learn: 0.7483647	total: 704ms	remaining: 0us
# 0:	learn: 1.4867062	total: 7.72ms	remaining: 764ms
# 50:	learn: 0.8300087	total: 357ms	remaining: 343ms
# 99:	learn: 0.7237952	total: 696ms	remaining: 0us
# 0:	learn: 1.5248060	total: 7.02ms	remaining: 695ms
# 50:	learn: 0.8535901	total: 353ms	remaining: 339ms
# 99:	learn: 0.7003687	total: 697ms	remaining: 0us
# 0:	learn: 1.5450173	total: 7.56ms	remaining: 749ms
# 50:	learn: 0.9788889	total: 363ms	remaining: 348ms
# 99:	learn: 0.8670031	total: 700ms	remaining: 0us
# 0:	learn: 1.5144105	total: 8ms	remaining: 792ms
# 50:	learn: 0.9565405	total: 359ms	remaining: 345ms
# 99:	learn: 0.8189846	total: 696ms	remaining: 0us
# 0:	learn: 1.5481016	total: 7.32ms	remaining: 725ms
# 50:	learn: 1.0068122	total: 362ms	remaining: 348ms
# 99:	learn: 0.8599621	total: 696ms	remaining: 0us
# 0:	learn: 1.3281403	total: 7.65ms	remaining: 758ms
# 50:	learn: 0.5996078	total: 350ms	remaining: 337ms
# 99:	learn: 0.4619890	total: 683ms	remaining: 0us
# 0:	learn: 1.2945366	total: 7.02ms	remaining: 695ms
# 50:	learn: 0.5670628	total: 345ms	remaining: 332ms
# 99:	learn: 0.4134135	total: 677ms	remaining: 0us
# 0:	learn: 1.3626795	total: 7.31ms	remaining: 723ms
# 50:	learn: 0.4789239	total: 372ms	remaining: 357ms
# 99:	learn: 0.3041965	total: 714ms	remaining: 0us
# 0:	learn: 1.5176762	total: 11.8ms	remaining: 1.76s
# 50:	learn: 0.8557802	total: 382ms	remaining: 741ms
# 100:	learn: 0.7473102	total: 743ms	remaining: 361ms
# 149:	learn: 0.6602652	total: 1.09s	remaining: 0us
# 0:	learn: 1.4867062	total: 7.57ms	remaining: 1.13s
# 50:	learn: 0.8300087	total: 357ms	remaining: 693ms
# 100:	learn: 0.7230209	total: 710ms	remaining: 345ms
# 149:	learn: 0.6359761	total: 1.05s	remaining: 0us
# 0:	learn: 1.5248060	total: 7.42ms	remaining: 1.1s
# 50:	learn: 0.8535901	total: 361ms	remaining: 700ms
# 100:	learn: 0.6974757	total: 704ms	remaining: 342ms
# 149:	learn: 0.6053879	total: 1.04s	remaining: 0us
# 0:	learn: 1.5450173	total: 8.2ms	remaining: 1.22s
# 50:	learn: 0.9788889	total: 365ms	remaining: 709ms
# 100:	learn: 0.8660512	total: 705ms	remaining: 342ms
# 149:	learn: 0.8004922	total: 1.04s	remaining: 0us
# 0:	learn: 1.5144105	total: 7.57ms	remaining: 1.13s
# 50:	learn: 0.9565405	total: 365ms	remaining: 708ms
# 100:	learn: 0.8179559	total: 716ms	remaining: 347ms
# 149:	learn: 0.7573533	total: 1.06s	remaining: 0us
# 0:	learn: 1.5481016	total: 7.97ms	remaining: 1.19s
# 50:	learn: 1.0068122	total: 366ms	remaining: 710ms
# 100:	learn: 0.8571918	total: 719ms	remaining: 349ms
# 149:	learn: 0.7772616	total: 1.08s	remaining: 0us
# 0:	learn: 1.3281403	total: 7.5ms	remaining: 1.12s
# 50:	learn: 0.5996078	total: 358ms	remaining: 695ms
# 100:	learn: 0.4612105	total: 709ms	remaining: 344ms
# 149:	learn: 0.3503948	total: 1.07s	remaining: 0us
# 0:	learn: 1.2945366	total: 7.18ms	remaining: 1.07s
# 50:	learn: 0.5670628	total: 367ms	remaining: 712ms
# 100:	learn: 0.4118773	total: 724ms	remaining: 351ms
# 149:	learn: 0.3124765	total: 1.06s	remaining: 0us
# 0:	learn: 1.3626795	total: 7.33ms	remaining: 1.09s
# 50:	learn: 0.4789239	total: 356ms	remaining: 691ms
# 100:	learn: 0.3016890	total: 705ms	remaining: 342ms
# 149:	learn: 0.2371883	total: 1.04s	remaining: 0us
# 0:	learn: 1.5215336	total: 82ms	remaining: 24.5s
# 50:	learn: 0.8648415	total: 4.35s	remaining: 21.3s
# 100:	learn: 0.7493753	total: 8.53s	remaining: 16.8s
# 150:	learn: 0.6617759	total: 12.8s	remaining: 12.6s
# 200:	learn: 0.5948330	total: 17s	remaining: 8.36s
# 250:	learn: 0.5406414	total: 21.2s	remaining: 4.14s
# 299:	learn: 0.4976318	total: 25.2s	remaining: 0us
# 0:	learn: 1.4906967	total: 78.6ms	remaining: 23.5s
# 50:	learn: 0.8362524	total: 4.12s	remaining: 20.1s
# 100:	learn: 0.7019429	total: 7.99s	remaining: 15.7s
# 150:	learn: 0.6127270	total: 11.9s	remaining: 11.8s
# 200:	learn: 0.5421207	total: 15.7s	remaining: 7.74s
# 250:	learn: 0.4864837	total: 19.6s	remaining: 3.82s
# 299:	learn: 0.4456594	total: 23.3s	remaining: 0us
# 0:	learn: 1.5329571	total: 86.6ms	remaining: 25.9s
# 50:	learn: 0.8603397	total: 4.41s	remaining: 21.5s
# 100:	learn: 0.6945672	total: 8.62s	remaining: 17s
# 150:	learn: 0.5976169	total: 12.9s	remaining: 12.7s
# 200:	learn: 0.5282298	total: 17.1s	remaining: 8.44s
# 250:	learn: 0.4692311	total: 21.3s	remaining: 4.17s
# 299:	learn: 0.4248268	total: 25.7s	remaining: 0us
# 0:	learn: 1.5469782	total: 92.9ms	remaining: 27.8s
# 50:	learn: 0.9826937	total: 4.49s	remaining: 21.9s
# 100:	learn: 0.8557456	total: 8.77s	remaining: 17.3s
# 150:	learn: 0.7889576	total: 12.9s	remaining: 12.7s
# 200:	learn: 0.7287881	total: 17s	remaining: 8.39s
# 250:	learn: 0.6830846	total: 21.3s	remaining: 4.15s
# 299:	learn: 0.6485704	total: 25.3s	remaining: 0us
# 0:	learn: 1.5164295	total: 76.6ms	remaining: 22.9s
# 50:	learn: 0.9670860	total: 4.07s	remaining: 19.9s
# 100:	learn: 0.8315192	total: 7.91s	remaining: 15.6s
# 150:	learn: 0.7620764	total: 11.7s	remaining: 11.6s
# 200:	learn: 0.7068830	total: 15.5s	remaining: 7.65s
# 250:	learn: 0.6581738	total: 19.5s	remaining: 3.8s
# 299:	learn: 0.6217195	total: 23.3s	remaining: 0us
# 0:	learn: 1.5522276	total: 86.2ms	remaining: 25.8s
# 50:	learn: 1.0166153	total: 4.4s	remaining: 21.5s
# 100:	learn: 0.8693316	total: 8.74s	remaining: 17.2s
# 150:	learn: 0.7785024	total: 13.1s	remaining: 12.9s
# 200:	learn: 0.6999701	total: 17.3s	remaining: 8.53s
# 250:	learn: 0.6452587	total: 21.7s	remaining: 4.23s
# 299:	learn: 0.5987667	total: 25.8s	remaining: 0us
# 0:	learn: 1.3440546	total: 82.2ms	remaining: 24.6s
# 50:	learn: 0.5402970	total: 4.35s	remaining: 21.3s
# 100:	learn: 0.4059353	total: 8.55s	remaining: 16.8s
# 150:	learn: 0.3155319	total: 12.7s	remaining: 12.5s
# 200:	learn: 0.2473541	total: 16.9s	remaining: 8.31s
# 250:	learn: 0.2026395	total: 21.1s	remaining: 4.11s
# 299:	learn: 0.1700327	total: 25.2s	remaining: 0us
# 0:	learn: 1.3118472	total: 84.3ms	remaining: 25.2s
# 50:	learn: 0.5743372	total: 4.03s	remaining: 19.7s
# 100:	learn: 0.4063318	total: 7.98s	remaining: 15.7s
# 150:	learn: 0.2971060	total: 11.8s	remaining: 11.6s
# 200:	learn: 0.2276793	total: 15.6s	remaining: 7.69s
# 250:	learn: 0.1818107	total: 19.5s	remaining: 3.81s
# 299:	learn: 0.1479663	total: 23.2s	remaining: 0us
# 0:	learn: 1.3982537	total: 86.6ms	remaining: 25.9s
# 50:	learn: 0.4960007	total: 4.53s	remaining: 22.1s
# 100:	learn: 0.3418950	total: 8.77s	remaining: 17.3s
# 150:	learn: 0.2465115	total: 12.9s	remaining: 12.8s
# 200:	learn: 0.2012612	total: 17.1s	remaining: 8.41s
# 250:	learn: 0.1656691	total: 21.2s	remaining: 4.14s
# 299:	learn: 0.1390034	total: 25.4s	remaining: 0us
# 0:	learn: 1.3374870	total: 7.44ms	remaining: 1.11s
# 50:	learn: 0.6235107	total: 356ms	remaining: 691ms
# 100:	learn: 0.5014172	total: 708ms	remaining: 344ms
# 149:	learn: 0.4205787	total: 1.06s	remaining: 0us
# GridSearchCV(cv=3,
#              estimator=<catboost.core.CatBoostRegressor object at 0x0000023E1AECD160>,
#              param_grid={'depth': [2, 4, 6], 'iterations': [100, 150, 300],
#                          'learning_rate': [0.1, 0.05, 0.5]},
#              refit='rmse', return_train_score=True,
#              scoring={'r2': make_scorer(r2_score, response_method='predict'),
#                       'rmse': make_scorer(rmse, response_method='predict')})

# %%
# Лучшая модель
best_model = grid_search.best_estimator_
print("\nЛучшие параметры:", grid_search.best_params_)
print("Лучшая RMSE (кросс-валидация):", grid_search.best_score_)

# Предсказание на тестовом наборе
y_pred = best_model.predict(X_test_processed)
test_rmse = rmse(y_test, y_pred)
test_r2 = r2_score(y_test, y_pred)

print("\nТестовая RMSE:", test_rmse)
print("Тестовый R2:", test_r2)

# Сравнение с baseline
baseline_pred = np.full_like(y_test, y_train.mean())
baseline_rmse = rmse(y_test, baseline_pred)
print("\nBaseline RMSE (предсказание средним):", baseline_rmse)
print("Улучшение над baseline:", round((1 - test_rmse/baseline_rmse)*100, 1), "%")
# Out:
# Лучшие параметры: {'depth': 6, 'iterations': 150, 'learning_rate': 0.5}
# Лучшая RMSE (кросс-валидация): 1.3086887076572353
#
# Тестовая RMSE: 1.3748875050806573
# Тестовый R2: 0.21771868495812619
#
# Baseline RMSE (предсказание средним): 1.554975592379904
# Улучшение над baseline: 11.6 %

# %%
pool = Pool(X_train_processed, y_train, cat_features=cat_features, feature_names=list(X_train_processed.columns))

best_model.plot_tree(
    tree_idx=0,
    pool=pool
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Используемое устройство: {device}")

# Подготовка данных
features = cat_features + numeric_features + bool_features
y = np.log1p(df['CC50, mM'])
X = df[features]

# Разделение выборки
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.15, random_state=62025
)

# Обработка для нейросети

# Создаем преобразователь признаков
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features),
        ('bool', 'passthrough', bool_features)
    ],
    remainder='drop'
)

# Применяем преобразования
X_train_pt = preprocessor.fit_transform(X_train)
X_test_pt = preprocessor.transform(X_test)

# Преобразование в тензоры PyTorch
X_train_tensor = torch.tensor(X_train_pt.astype(np.float32), device=device)
y_train_tensor = torch.tensor(y_train.values.astype(np.float32), device=device)
X_test_tensor = torch.tensor(X_test_pt.astype(np.float32), device=device)
y_test_tensor = torch.tensor(y_test.values.astype(np.float32), device=device)

# Создание DataLoader
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

batch_size = 128
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Определяем размерность входа
input_dim = X_train_pt.shape[1]

# Сама структура сети
class RegressionNN(nn.Module):
    def __init__(self, input_size):
        super(RegressionNN, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 1024),
            nn.ReLU(),
            nn.BatchNorm1d(1024),
            nn.Dropout(0.5),

            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.BatchNorm1d(512),
            nn.Dropout(0.75),

            nn.Linear(512, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.5),

            nn.Linear(256, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Dropout(0.3),

            nn.Linear(128, 64),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Dropout(0.3),
            
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.BatchNorm1d(32),
            nn.Dropout(0.2),
            
            nn.Linear(32, 1)
        )
    
    def forward(self, x):
        return self.layers(x)

# Инициализация модели
model_pt = RegressionNN(input_dim).to(device)

# Функция потерь и оптимизатор
criterion = nn.MSELoss()
optimizer = optim.Adam(model_pt.parameters(), lr=0.01)

# Планировщик скорости обучения
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.2, patience=5, verbose=True
)

# ОБУЧЕНИЕ МОДЕЛИ

num_epochs = 100
best_loss = float('inf')
patience = 15
patience_counter = 0

# Цикл обучения
for epoch in range(num_epochs):
    # Режим обучения
    model_pt.train()
    train_loss = 0.0
    
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        
        # Forward pass
        outputs = model_pt(inputs)
        loss = criterion(outputs, targets.unsqueeze(1))
        
        # Backward pass и оптимизация
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * inputs.size(0)
    
    # Средняя потеря за эпоху
    train_loss /= len(train_loader.dataset)
    
    # Режим оценки
    model_pt.eval()
    val_loss = 0.0
    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model_pt(inputs)
            loss = criterion(outputs, targets.unsqueeze(1))
            val_loss += loss.item() * inputs.size(0)
    
    val_loss /= len(test_loader.dataset)
    scheduler.step(val_loss)
    
    # Вывод статистики
    print(f'Epoch [{epoch+1}/{num_epochs}] | '
          f'Train Loss: {train_loss:.6f} | Val Loss: {val_loss:.6f}')
    # Ранняя остановка
    if val_loss < best_loss:
        best_loss = val_loss
        patience_counter = 0
        # Сохранение лучшей модели
        torch.save(model_pt.state_dict(), 'best_model_pt.pth')
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f'Ранняя остановка на эпохе {epoch+1}')
            break
# Out:
# Используемое устройство: cuda
# D:\jupiter\conda_inst\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/100] | Train Loss: 32.078181 | Val Loss: 27.587067
# Epoch [2/100] | Train Loss: 28.487035 | Val Loss: 18.822535
# Epoch [3/100] | Train Loss: 23.331129 | Val Loss: 14.599266
# Epoch [4/100] | Train Loss: 15.744485 | Val Loss: 9.015267
# Epoch [5/100] | Train Loss: 8.169019 | Val Loss: 3.608982
# Epoch [6/100] | Train Loss: 4.095251 | Val Loss: 2.409921
# Epoch [7/100] | Train Loss: 3.405005 | Val Loss: 3.595481
# Epoch [8/100] | Train Loss: 3.559952 | Val Loss: 2.450306
# Epoch [9/100] | Train Loss: 2.774099 | Val Loss: 2.273061
# Epoch [10/100] | Train Loss: 2.583957 | Val Loss: 2.509867
# Epoch [11/100] | Train Loss: 2.707143 | Val Loss: 2.275867
# Epoch [12/100] | Train Loss: 2.531953 | Val Loss: 1.917137
# Epoch [13/100] | Train Loss: 2.216914 | Val Loss: 1.946611
# Epoch [14/100] | Train Loss: 2.252577 | Val Loss: 1.860486
# Epoch [15/100] | Train Loss: 2.306086 | Val Loss: 1.746576
# Epoch [16/100] | Train Loss: 2.256519 | Val Loss: 1.745295
# Epoch [17/100] | Train Loss: 2.003266 | Val Loss: 1.681871
# Epoch [18/100] | Train Loss: 1.984316 | Val Loss: 1.623095
# Epoch [19/100] | Train Loss: 1.854101 | Val Loss: 1.630442
# Epoch [20/100] | Train Loss: 1.822889 | Val Loss: 1.656024
# Epoch [21/100] | Train Loss: 1.743901 | Val Loss: 1.650046
# Epoch [22/100] | Train Loss: 1.820955 | Val Loss: 1.628149
# Epoch [23/100] | Train Loss: 1.693394 | Val Loss: 1.657750
# Epoch [24/100] | Train Loss: 1.603222 | Val Loss: 1.610987
# Epoch [25/100] | Train Loss: 1.635866 | Val Loss: 1.486741
# Epoch [26/100] | Train Loss: 1.697339 | Val Loss: 1.540338
# Epoch [27/100] | Train Loss: 1.697370 | Val Loss: 1.659464
# Epoch [28/100] | Train Loss: 1.566797 | Val Loss: 1.575564
# Epoch [29/100] | Train Loss: 1.572920 | Val Loss: 1.529771
# Epoch [30/100] | Train Loss: 1.453367 | Val Loss: 1.550644
# Epoch [31/100] | Train Loss: 1.482247 | Val Loss: 1.605701
# Epoch [32/100] | Train Loss: 1.450712 | Val Loss: 1.576362
# Epoch [33/100] | Train Loss: 1.541768 | Val Loss: 1.569102
# Epoch [34/100] | Train Loss: 1.520385 | Val Loss: 1.561513
# Epoch [35/100] | Train Loss: 1.435053 | Val Loss: 1.528837
# Epoch [36/100] | Train Loss: 1.424456 | Val Loss: 1.543782
# Epoch [37/100] | Train Loss: 1.518689 | Val Loss: 1.541552
# Epoch [38/100] | Train Loss: 1.499560 | Val Loss: 1.524646
# Epoch [39/100] | Train Loss: 1.502573 | Val Loss: 1.502453
# Epoch [40/100] | Train Loss: 1.387979 | Val Loss: 1.518042
# Ранняя остановка на эпохе 40

# %%
# ОЦЕНКА МОДЕЛИ
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Предсказание на тестовом наборе
all_preds = []
with torch.no_grad():
    for inputs, _ in test_loader:
        inputs = inputs.to(device)
        outputs = model_pt(inputs)
        all_preds.append(outputs.cpu().numpy())

y_pred_pt = np.concatenate(all_preds).flatten()

# Расчет метрик
test_rmse_pt = rmse(y_test, y_pred_pt)
test_r2_pt = r2_score(y_test, y_pred_pt)

print("\n[PyTorch] Тестовая RMSE:", test_rmse_pt)
print("[PyTorch] Тестовый R2:", test_r2_pt)
# Out:
# [PyTorch] Тестовая RMSE: 1.2320883898816266
# [PyTorch] Тестовый R2: 0.371779133846336

# %% [markdown]
# # Вывод:
# Лучше в предсказании себя показывает нейронная сеть, она может строить более сложные зависимости, однако выбор отдади модели CAT BOOST из-за возможности интерпретировать результат.
# При этом, качетво моделей не достаточно высокое.
